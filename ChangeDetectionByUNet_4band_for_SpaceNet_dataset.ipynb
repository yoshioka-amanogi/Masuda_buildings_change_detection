# %%
import csv
import sys
import glob, os
import copy
import gc
from tqdm import tqdm
import time
import math
from PIL import Image
import cv2
from shapely.geometry import MultiPolygon, Polygon, Point
import shapely.wkt
import shapely.affinity
import rasterio as rio
from rasterio.enums import Resampling
from rasterio.plot import show
import rasterio.mask
import gdal
import ogr
import numpy as np
import random
import pandas as pd
import tifffile as tiff
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import itertools
import psutil
sys.setrecursionlimit(10**6)
from skimage import morphology
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, models, transforms
from torch.utils.data import DataLoader, TensorDataset
from torch.utils.data.dataset import Subset
from torchsummary import summary
#import segmentation_models_pytorch as smp
#from segmentation_models_pytorch.encoders import get_preprocessing_fn
import pytorch_lightning as pl
from pytorch_lightning import Trainer
from pytorch_lightning import LightningModule
from pytorch_lightning.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
import albumentations as album

# %%
print(torch.cuda.is_available())
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# True

# %%
#  get data list
path_3band = '../building_detection_data/3band_train/3band/'
path_8band = '../building_detection_data/8band_train/8band/'
path_3band_test = '../building_detection_data/3band_test/'
path_8band_test = '../building_detection_data/8band_test/'
path_geojson = '../building_detection_data/geojson_train/'
path_mask_img = '../building_detection_data/MaskImages/'

def get_list(path):
    return [f for f in os.listdir(path) if not f.startswith('.')]

list_3band = get_list(path_3band)
list_8band = get_list(path_8band)
list_geojson = get_list(path_geojson)

list_3band_test = get_list(path_3band_test)
list_8band_test = get_list(path_8band_test)

# %%
os.listdir(path_geojson)
# Out:
# ['Geo_AOI_1_RIO_img1.geojson',
#  'Geo_AOI_1_RIO_img10.geojson',
#  'Geo_AOI_1_RIO_img100.geojson',
#  'Geo_AOI_1_RIO_img1000.geojson',
#  'Geo_AOI_1_RIO_img1001.geojson',
#  'Geo_AOI_1_RIO_img1002.geojson',
#  'Geo_AOI_1_RIO_img1003.geojson',
#  'Geo_AOI_1_RIO_img1004.geojson',
#  'Geo_AOI_1_RIO_img1005.geojson',
#  'Geo_AOI_1_RIO_img1006.geojson',
#  'Geo_AOI_1_RIO_img1007.geojson',
#  'Geo_AOI_1_RIO_img1008.geojson',
#  'Geo_AOI_1_RIO_img1009.geojson',
#  'Geo_AOI_1_RIO_img101.geojson',
#  'Geo_AOI_1_RIO_img1010.geojson',
#  'Geo_AOI_1_RIO_img1011.geojson',
#  'Geo_AOI_1_RIO_img1012.geojson',
#  'Geo_AOI_1_RIO_img1013.geojson',
#  'Geo_AOI_1_RIO_img1014.geojson',
#  'Geo_AOI_1_RIO_img1015.geojson',
#  'Geo_AOI_1_RIO_img1016.geojson',
#  'Geo_AOI_1_RIO_img1017.geojson',
#  'Geo_AOI_1_RIO_img1018.geojson',
#  'Geo_AOI_1_RIO_img3904.geojson',
#  'Geo_AOI_1_RIO_img3905.geojson',
#  'Geo_AOI_1_RIO_img3906.geojson',
#  'Geo_AOI_1_RIO_img3907.geojson',
#  'Geo_AOI_1_RIO_img3908.geojson',
#  'Geo_AOI_1_RIO_img3909.geojson',
#  'Geo_AOI_1_RIO_img391.geojson',
#  'Geo_AOI_1_RIO_img3910.geojson',
#  'Geo_AOI_1_RIO_img3911.geojson',
#  'Geo_AOI_1_RIO_img3912.geojson',
#  'Geo_AOI_1_RIO_img3913.geojson',
#  'Geo_AOI_1_RIO_img3914.geojson',
#  'Geo_AOI_1_RIO_img3915.geojson',
#  'Geo_AOI_1_RIO_img3916.geojson',
#  'Geo_AOI_1_RIO_img2719.geojson',
#  'Geo_AOI_1_RIO_img272.geojson',
#  'Geo_AOI_1_RIO_img2720.geojson',
#  'Geo_AOI_1_RIO_img2721.geojson',
#  'Geo_AOI_1_RIO_img2722.geojson',
#  'Geo_AOI_1_RIO_img2723.geojson',
#  'Geo_AOI_1_RIO_img6821.geojson',
#  'Geo_AOI_1_RIO_img6822.geojson',
#  'Geo_AOI_1_RIO_img6823.geojson',
#  'Geo_AOI_1_RIO_img6824.geojson',
#  'Geo_AOI_1_RIO_img6825.geojson',
#  'Geo_AOI_1_RIO_img6826.geojson',
#  'Geo_AOI_1_RIO_img6827.geojson',
#  'Geo_AOI_1_RIO_img6828.geojson',
#  'Geo_AOI_1_RIO_img6829.geojson',
#  'Geo_AOI_1_RIO_img683.geojson',
#  'Geo_AOI_1_RIO_img6830.geojson',
#  'Geo_AOI_1_RIO_img6831.geojson',
#  'Geo_AOI_1_RIO_img6832.geojson',
#  'Geo_AOI_1_RIO_img6833.geojson',
#  ...]

# %% [markdown]
# open sat imgs trial

# %%
img = rio.open('../building_detection_data/3band_train/3band/3band_AOI_1_RIO_img3745.tif')
data = img.read(out_shape=(448, 448), resampling=Resampling.bilinear)

data = data.transpose(1,2,0)
if data.max()!= 0:
    data = data / data.max()
print(data.shape)
img = np.array(data)
plt.imshow(img)
# Out:
# (448, 448, 3)

# %%
img = rio.open('../building_detection_data/3band_train/3band/3band_AOI_1_RIO_img3745.tif')
data = img.read(out_shape=(224, 224), resampling=Resampling.bilinear)
data = data.transpose(1,2,0)
img = np.array(data)
img[:,:,0].max()
# Out:
# 242

# %%
img = rio.open('../building_detection_data/8band_train/8band/8band_AOI_1_RIO_img3745.tif')
data = img.read(out_shape=(224, 224), resampling=Resampling.bilinear)
data = data.transpose(1,2,0)
data = np.stack([data[:,:,1], data[:,:,2], data[:,:,4]], axis=2)
if data.max()!= 0:
    data = data / data.max()
print(data.shape)
img = np.array(data)
plt.imshow(img)
# Out:
# (224, 224, 3)

# %%
img = rio.open('../building_detection_data/8band_train/8band/8band_AOI_1_RIO_img3745.tif')
data = img.read(out_shape=(224, 224), resampling=Resampling.bilinear)
data = data.transpose(1,2,0)
img = np.array(data)
img[:,:,6].max()
# Out:
# 6265

# %%
import os
print(len(os.listdir("../building_detection_data/3band_train/3band")))
print(len(os.listdir("../building_detection_data/8band_train/8band")))
print(len(os.listdir("../building_detection_data/MaskImages")))
print(len(os.listdir("../building_detection_data/3band_test")))
print(len(os.listdir("../building_detection_data/8band_test")))
# Out:
# 6940
# 6940
# 6940
# 2795
# 2795

# %%
mask = rio.open('../building_detection_data/MaskImages/AOI_1_RIO_img3745.tif')
data = mask.read()
data = data.transpose(1,2,0)
print(data.shape)
mask = np.array(data)
plt.imshow(mask)
# Out:
# (406, 439, 1)

# %% [markdown]
# create mask images

# %%
def create_poly_mask(rasterSrc, vectorSrc, npDistFileName=''):

    # load vector
    source_ds = ogr.Open(vectorSrc)
    source_layer = source_ds.GetLayer()

	# load raster
    srcRas_ds = gdal.Open(rasterSrc)
    cols = srcRas_ds.RasterXSize
    rows = srcRas_ds.RasterYSize
        
    dstPath = npDistFileName

	# create mask img
    memdrv = gdal.GetDriverByName('GTiff') 
    dst_ds = memdrv.Create(dstPath, cols, rows, 1, gdal.GDT_Byte)
    dst_ds.SetGeoTransform(srcRas_ds.GetGeoTransform())
    dst_ds.SetProjection(srcRas_ds.GetProjection())
    band = dst_ds.GetRasterBand(1)
    band.SetNoDataValue(0)
    gdal.RasterizeLayer(dst_ds, [1], source_layer, burn_values=[255], options=['COMPRESS=LZW'])
    dst_ds = 0
    
    mask_image = Image.open(dstPath)
    mask_image = np.array(mask_image)
    
    return mask_image


def build_labels(src_raster_dir, src_vector_dir, dst_dir):
	
    os.makedirs(dst_dir, exist_ok=True)

    file_count = len([f for f in os.walk(src_vector_dir).__next__()[2] if f[-8:] == ".geojson"])

    print("[INFO] Found {} geojson files. Preparing building mask images...".format(file_count))

    for idx in tqdm(range(1, file_count + 1)):

        src_raster_filename = "3band_AOI_1_RIO_img{}.tif".format(idx)
        src_vector_filename = "Geo_AOI_1_RIO_img{}.geojson".format(idx)
        dst_filename = "AOI_1_RIO_img{}.tif".format(idx)

        src_raster_path = os.path.join(src_raster_dir, src_raster_filename)
        src_vector_path = os.path.join(src_vector_dir, src_vector_filename)
        dst_path = os.path.join(dst_dir, dst_filename)

        create_poly_mask(
            src_raster_path, src_vector_path, npDistFileName=dst_path
        )

# %%
import os
os.listdir("../building_detection_data/MaskImages")
# Out:
# ['AOI_1_RIO_img1.tif',
#  'AOI_1_RIO_img10.tif',
#  'AOI_1_RIO_img100.tif',
#  'AOI_1_RIO_img1000.tif',
#  'AOI_1_RIO_img1001.tif',
#  'AOI_1_RIO_img1002.tif',
#  'AOI_1_RIO_img1003.tif',
#  'AOI_1_RIO_img1004.tif',
#  'AOI_1_RIO_img1005.tif',
#  'AOI_1_RIO_img1006.tif',
#  'AOI_1_RIO_img1007.tif',
#  'AOI_1_RIO_img1008.tif',
#  'AOI_1_RIO_img1009.tif',
#  'AOI_1_RIO_img101.tif',
#  'AOI_1_RIO_img1010.tif',
#  'AOI_1_RIO_img1011.tif',
#  'AOI_1_RIO_img1012.tif',
#  'AOI_1_RIO_img1013.tif',
#  'AOI_1_RIO_img1014.tif',
#  'AOI_1_RIO_img1015.tif',
#  'AOI_1_RIO_img1016.tif',
#  'AOI_1_RIO_img1017.tif',
#  'AOI_1_RIO_img1018.tif',
#  'AOI_1_RIO_img1019.tif',
#  'AOI_1_RIO_img2530.tif',
#  'AOI_1_RIO_img2531.tif',
#  'AOI_1_RIO_img2532.tif',
#  'AOI_1_RIO_img2533.tif',
#  'AOI_1_RIO_img2534.tif',
#  'AOI_1_RIO_img2535.tif',
#  'AOI_1_RIO_img2536.tif',
#  'AOI_1_RIO_img2537.tif',
#  'AOI_1_RIO_img2538.tif',
#  'AOI_1_RIO_img2539.tif',
#  'AOI_1_RIO_img254.tif',
#  'AOI_1_RIO_img2540.tif',
#  'AOI_1_RIO_img2541.tif',
#  'AOI_1_RIO_img2542.tif',
#  'AOI_1_RIO_img2543.tif',
#  'AOI_1_RIO_img4130.tif',
#  'AOI_1_RIO_img4131.tif',
#  'AOI_1_RIO_img4132.tif',
#  'AOI_1_RIO_img4133.tif',
#  'AOI_1_RIO_img4134.tif',
#  'AOI_1_RIO_img4135.tif',
#  'AOI_1_RIO_img4136.tif',
#  'AOI_1_RIO_img4137.tif',
#  'AOI_1_RIO_img4138.tif',
#  'AOI_1_RIO_img4139.tif',
#  'AOI_1_RIO_img414.tif',
#  'AOI_1_RIO_img4140.tif',
#  'AOI_1_RIO_img4141.tif',
#  'AOI_1_RIO_img4142.tif',
#  'AOI_1_RIO_img4143.tif',
#  'AOI_1_RIO_img5630.tif',
#  'AOI_1_RIO_img5631.tif',
#  'AOI_1_RIO_img5632.tif',
#  'AOI_1_RIO_img5633.tif',
#  'AOI_1_RIO_img5634.tif',
#  'AOI_1_RIO_img5635.tif',
#  'AOI_1_RIO_img5636.tif',
#  'AOI_1_RIO_img5637.tif',
#  'AOI_1_RIO_img5638.tif',
#  'AOI_1_RIO_img5639.tif',
#  'AOI_1_RIO_img564.tif',
#  'AOI_1_RIO_img5640.tif',
#  'AOI_1_RIO_img5641.tif',
#  'AOI_1_RIO_img5642.tif',
#  'AOI_1_RIO_img5643.tif',
#  'AOI_1_RIO_img102.tif',
#  'AOI_1_RIO_img104.tif',
#  'AOI_1_RIO_img106.tif',
#  'AOI_1_RIO_img108.tif',
#  'AOI_1_RIO_img11.tif',
#  'AOI_1_RIO_img111.tif',
#  'AOI_1_RIO_img113.tif',
#  'AOI_1_RIO_img1144.tif',
#  'AOI_1_RIO_img116.tif',
#  'AOI_1_RIO_img118.tif',
#  'AOI_1_RIO_img12.tif',
#  'AOI_1_RIO_img122.tif',
#  'AOI_1_RIO_img124.tif',
#  'AOI_1_RIO_img126.tif',
#  'AOI_1_RIO_img128.tif',
#  'AOI_1_RIO_img790.tif',
#  'AOI_1_RIO_img791.tif',
#  'AOI_1_RIO_img792.tif',
#  'AOI_1_RIO_img793.tif',
#  'AOI_1_RIO_img794.tif',
#  'AOI_1_RIO_img795.tif',
#  'AOI_1_RIO_img796.tif',
#  'AOI_1_RIO_img797.tif',
#  'AOI_1_RIO_img798.tif',
#  'AOI_1_RIO_img799.tif',
#  'AOI_1_RIO_img1260.tif',
#  'AOI_1_RIO_img1261.tif',
#  'AOI_1_RIO_img1262.tif',
#  'AOI_1_RIO_img1263.tif',
#  'AOI_1_RIO_img1264.tif',
#  'AOI_1_RIO_img1265.tif',
#  'AOI_1_RIO_img1266.tif',
#  'AOI_1_RIO_img1267.tif',
#  'AOI_1_RIO_img1268.tif',
#  'AOI_1_RIO_img1269.tif',
#  'AOI_1_RIO_img127.tif',
#  'AOI_1_RIO_img1270.tif',
#  'AOI_1_RIO_img1271.tif',
#  'AOI_1_RIO_img1272.tif',
#  'AOI_1_RIO_img1273.tif',
#  'AOI_1_RIO_img1274.tif',
#  'AOI_1_RIO_img1275.tif',
#  'AOI_1_RIO_img1276.tif',
#  'AOI_1_RIO_img1277.tif',
#  'AOI_1_RIO_img1278.tif',
#  'AOI_1_RIO_img1279.tif',
#  'AOI_1_RIO_img1420.tif',
#  'AOI_1_RIO_img1421.tif',
#  'AOI_1_RIO_img1422.tif',
#  'AOI_1_RIO_img1423.tif',
#  'AOI_1_RIO_img1424.tif',
#  'AOI_1_RIO_img1425.tif',
#  'AOI_1_RIO_img1426.tif',
#  'AOI_1_RIO_img1427.tif',
#  'AOI_1_RIO_img1428.tif',
#  'AOI_1_RIO_img1429.tif',
#  'AOI_1_RIO_img160.tif',
#  'AOI_1_RIO_img1600.tif',
#  'AOI_1_RIO_img1601.tif',
#  'AOI_1_RIO_img1602.tif',
#  'AOI_1_RIO_img1603.tif',
#  'AOI_1_RIO_img1604.tif',
#  'AOI_1_RIO_img1605.tif',
#  'AOI_1_RIO_img1606.tif',
#  'AOI_1_RIO_img1607.tif',
#  'AOI_1_RIO_img1608.tif',
#  'AOI_1_RIO_img1609.tif',
#  'AOI_1_RIO_img1710.tif',
#  'AOI_1_RIO_img1711.tif',
#  'AOI_1_RIO_img1712.tif',
#  'AOI_1_RIO_img1713.tif',
#  'AOI_1_RIO_img1714.tif',
#  'AOI_1_RIO_img1715.tif',
#  'AOI_1_RIO_img1716.tif',
#  'AOI_1_RIO_img1717.tif',
#  'AOI_1_RIO_img1718.tif',
#  'AOI_1_RIO_img1719.tif',
#  'AOI_1_RIO_img172.tif',
#  'AOI_1_RIO_img1720.tif',
#  'AOI_1_RIO_img1721.tif',
#  'AOI_1_RIO_img1722.tif',
#  'AOI_1_RIO_img1723.tif',
#  'AOI_1_RIO_img190.tif',
#  'AOI_1_RIO_img1900.tif',
#  'AOI_1_RIO_img1901.tif',
#  'AOI_1_RIO_img1902.tif',
#  'AOI_1_RIO_img1903.tif',
#  'AOI_1_RIO_img1904.tif',
#  'AOI_1_RIO_img1905.tif',
#  'AOI_1_RIO_img1906.tif',
#  'AOI_1_RIO_img1907.tif',
#  'AOI_1_RIO_img1908.tif',
#  'AOI_1_RIO_img1909.tif',
#  'AOI_1_RIO_img2020.tif',
#  'AOI_1_RIO_img2021.tif',
#  'AOI_1_RIO_img2022.tif',
#  'AOI_1_RIO_img2023.tif',
#  'AOI_1_RIO_img2024.tif',
#  'AOI_1_RIO_img2025.tif',
#  'AOI_1_RIO_img2026.tif',
#  'AOI_1_RIO_img2027.tif',
#  'AOI_1_RIO_img2028.tif',
#  'AOI_1_RIO_img2029.tif',
#  'AOI_1_RIO_img2080.tif',
#  'AOI_1_RIO_img2081.tif',
#  'AOI_1_RIO_img2082.tif',
#  'AOI_1_RIO_img2083.tif',
#  'AOI_1_RIO_img2084.tif',
#  'AOI_1_RIO_img2085.tif',
#  'AOI_1_RIO_img2086.tif',
#  'AOI_1_RIO_img2087.tif',
#  'AOI_1_RIO_img2088.tif',
#  'AOI_1_RIO_img2089.tif',
#  'AOI_1_RIO_img2380.tif',
#  'AOI_1_RIO_img2381.tif',
#  'AOI_1_RIO_img2382.tif',
#  'AOI_1_RIO_img2383.tif',
#  'AOI_1_RIO_img2384.tif',
#  'AOI_1_RIO_img2385.tif',
#  'AOI_1_RIO_img2386.tif',
#  'AOI_1_RIO_img2387.tif',
#  'AOI_1_RIO_img2388.tif',
#  'AOI_1_RIO_img2389.tif',
#  'AOI_1_RIO_img239.tif',
#  'AOI_1_RIO_img2390.tif',
#  'AOI_1_RIO_img2391.tif',
#  'AOI_1_RIO_img2392.tif',
#  'AOI_1_RIO_img2393.tif',
#  'AOI_1_RIO_img2394.tif',
#  'AOI_1_RIO_img2395.tif',
#  'AOI_1_RIO_img2396.tif',
#  'AOI_1_RIO_img2397.tif',
#  'AOI_1_RIO_img2398.tif',
#  'AOI_1_RIO_img2399.tif',
#  'AOI_1_RIO_img2630.tif',
#  'AOI_1_RIO_img2631.tif',
#  'AOI_1_RIO_img2632.tif',
#  'AOI_1_RIO_img2633.tif',
#  'AOI_1_RIO_img2634.tif',
#  'AOI_1_RIO_img2635.tif',
#  'AOI_1_RIO_img2636.tif',
#  'AOI_1_RIO_img2637.tif',
#  'AOI_1_RIO_img2638.tif',
#  'AOI_1_RIO_img2639.tif',
#  'AOI_1_RIO_img264.tif',
#  'AOI_1_RIO_img2640.tif',
#  'AOI_1_RIO_img2641.tif',
#  'AOI_1_RIO_img2642.tif',
#  'AOI_1_RIO_img2643.tif',
#  'AOI_1_RIO_img2644.tif',
#  'AOI_1_RIO_img2645.tif',
#  'AOI_1_RIO_img2646.tif',
#  'AOI_1_RIO_img2647.tif',
#  'AOI_1_RIO_img2648.tif',
#  'AOI_1_RIO_img2649.tif',
#  'AOI_1_RIO_img2830.tif',
#  'AOI_1_RIO_img2831.tif',
#  'AOI_1_RIO_img2832.tif',
#  'AOI_1_RIO_img2833.tif',
#  'AOI_1_RIO_img2834.tif',
#  'AOI_1_RIO_img2835.tif',
#  'AOI_1_RIO_img2836.tif',
#  'AOI_1_RIO_img2837.tif',
#  'AOI_1_RIO_img2838.tif',
#  'AOI_1_RIO_img2839.tif',
#  'AOI_1_RIO_img284.tif',
#  'AOI_1_RIO_img2840.tif',
#  'AOI_1_RIO_img2841.tif',
#  'AOI_1_RIO_img2842.tif',
#  'AOI_1_RIO_img2843.tif',
#  'AOI_1_RIO_img2844.tif',
#  'AOI_1_RIO_img2845.tif',
#  'AOI_1_RIO_img2846.tif',
#  'AOI_1_RIO_img2847.tif',
#  'AOI_1_RIO_img2848.tif',
#  'AOI_1_RIO_img2849.tif',
#  'AOI_1_RIO_img2890.tif',
#  'AOI_1_RIO_img2891.tif',
#  'AOI_1_RIO_img2892.tif',
#  'AOI_1_RIO_img2893.tif',
#  'AOI_1_RIO_img2894.tif',
#  'AOI_1_RIO_img2895.tif',
#  'AOI_1_RIO_img2896.tif',
#  'AOI_1_RIO_img2897.tif',
#  'AOI_1_RIO_img2898.tif',
#  'AOI_1_RIO_img2899.tif',
#  'AOI_1_RIO_img3070.tif',
#  'AOI_1_RIO_img3071.tif',
#  'AOI_1_RIO_img3072.tif',
#  'AOI_1_RIO_img3073.tif',
#  'AOI_1_RIO_img3074.tif',
#  'AOI_1_RIO_img3075.tif',
#  'AOI_1_RIO_img3076.tif',
#  'AOI_1_RIO_img3077.tif',
#  'AOI_1_RIO_img3078.tif',
#  'AOI_1_RIO_img3079.tif',
#  'AOI_1_RIO_img3280.tif',
#  'AOI_1_RIO_img3281.tif',
#  'AOI_1_RIO_img3282.tif',
#  'AOI_1_RIO_img3283.tif',
#  'AOI_1_RIO_img3284.tif',
#  'AOI_1_RIO_img3285.tif',
#  'AOI_1_RIO_img3286.tif',
#  'AOI_1_RIO_img3287.tif',
#  'AOI_1_RIO_img3288.tif',
#  'AOI_1_RIO_img3289.tif',
#  'AOI_1_RIO_img3430.tif',
#  'AOI_1_RIO_img3431.tif',
#  'AOI_1_RIO_img3432.tif',
#  'AOI_1_RIO_img3433.tif',
#  'AOI_1_RIO_img3434.tif',
#  'AOI_1_RIO_img3435.tif',
#  'AOI_1_RIO_img3436.tif',
#  'AOI_1_RIO_img3437.tif',
#  'AOI_1_RIO_img3438.tif',
#  'AOI_1_RIO_img3439.tif',
#  'AOI_1_RIO_img344.tif',
#  'AOI_1_RIO_img3440.tif',
#  'AOI_1_RIO_img3441.tif',
#  'AOI_1_RIO_img3442.tif',
#  'AOI_1_RIO_img3443.tif',
#  'AOI_1_RIO_img3590.tif',
#  'AOI_1_RIO_img3591.tif',
#  'AOI_1_RIO_img3592.tif',
#  'AOI_1_RIO_img3593.tif',
#  'AOI_1_RIO_img3594.tif',
#  'AOI_1_RIO_img3595.tif',
#  'AOI_1_RIO_img3596.tif',
#  'AOI_1_RIO_img3597.tif',
#  'AOI_1_RIO_img3598.tif',
#  'AOI_1_RIO_img3599.tif',
#  'AOI_1_RIO_img36.tif',
#  'AOI_1_RIO_img360.tif',
#  'AOI_1_RIO_img3600.tif',
#  'AOI_1_RIO_img3601.tif',
#  'AOI_1_RIO_img3602.tif',
#  'AOI_1_RIO_img3603.tif',
#  'AOI_1_RIO_img3604.tif',
#  'AOI_1_RIO_img3605.tif',
#  'AOI_1_RIO_img3606.tif',
#  'AOI_1_RIO_img3607.tif',
#  'AOI_1_RIO_img3608.tif',
#  'AOI_1_RIO_img3609.tif',
#  'AOI_1_RIO_img3720.tif',
#  'AOI_1_RIO_img3721.tif',
#  'AOI_1_RIO_img3722.tif',
#  'AOI_1_RIO_img3723.tif',
#  'AOI_1_RIO_img3724.tif',
#  'AOI_1_RIO_img3725.tif',
#  'AOI_1_RIO_img3726.tif',
#  'AOI_1_RIO_img3727.tif',
#  'AOI_1_RIO_img3728.tif',
#  'AOI_1_RIO_img3729.tif',
#  'AOI_1_RIO_img3860.tif',
#  'AOI_1_RIO_img3861.tif',
#  'AOI_1_RIO_img3862.tif',
#  'AOI_1_RIO_img3863.tif',
#  'AOI_1_RIO_img3864.tif',
#  'AOI_1_RIO_img3865.tif',
#  'AOI_1_RIO_img3866.tif',
#  'AOI_1_RIO_img3867.tif',
#  'AOI_1_RIO_img3868.tif',
#  'AOI_1_RIO_img3869.tif',
#  'AOI_1_RIO_img430.tif',
#  'AOI_1_RIO_img4300.tif',
#  'AOI_1_RIO_img4301.tif',
#  'AOI_1_RIO_img4302.tif',
#  'AOI_1_RIO_img4303.tif',
#  'AOI_1_RIO_img4304.tif',
#  'AOI_1_RIO_img4305.tif',
#  'AOI_1_RIO_img4306.tif',
#  'AOI_1_RIO_img4307.tif',
#  'AOI_1_RIO_img4308.tif',
#  'AOI_1_RIO_img4309.tif',
#  'AOI_1_RIO_img4430.tif',
#  'AOI_1_RIO_img4431.tif',
#  'AOI_1_RIO_img4432.tif',
#  'AOI_1_RIO_img4433.tif',
#  'AOI_1_RIO_img4434.tif',
#  'AOI_1_RIO_img4435.tif',
#  'AOI_1_RIO_img4436.tif',
#  'AOI_1_RIO_img4437.tif',
#  'AOI_1_RIO_img4438.tif',
#  'AOI_1_RIO_img4439.tif',
#  'AOI_1_RIO_img444.tif',
#  'AOI_1_RIO_img4440.tif',
#  'AOI_1_RIO_img4441.tif',
#  'AOI_1_RIO_img4442.tif',
#  'AOI_1_RIO_img4443.tif',
#  'AOI_1_RIO_img4580.tif',
#  'AOI_1_RIO_img4581.tif',
#  'AOI_1_RIO_img4582.tif',
#  'AOI_1_RIO_img4583.tif',
#  'AOI_1_RIO_img4584.tif',
#  'AOI_1_RIO_img4585.tif',
#  'AOI_1_RIO_img4586.tif',
#  'AOI_1_RIO_img4587.tif',
#  'AOI_1_RIO_img4588.tif',
#  'AOI_1_RIO_img4589.tif',
#  'AOI_1_RIO_img4710.tif',
#  'AOI_1_RIO_img4711.tif',
#  'AOI_1_RIO_img4712.tif',
#  'AOI_1_RIO_img4713.tif',
#  'AOI_1_RIO_img4714.tif',
#  'AOI_1_RIO_img4715.tif',
#  'AOI_1_RIO_img4716.tif',
#  'AOI_1_RIO_img4717.tif',
#  'AOI_1_RIO_img4718.tif',
#  'AOI_1_RIO_img4719.tif',
#  'AOI_1_RIO_img472.tif',
#  'AOI_1_RIO_img4720.tif',
#  'AOI_1_RIO_img4721.tif',
#  'AOI_1_RIO_img4722.tif',
#  'AOI_1_RIO_img4723.tif',
#  'AOI_1_RIO_img4880.tif',
#  'AOI_1_RIO_img4881.tif',
#  'AOI_1_RIO_img4882.tif',
#  'AOI_1_RIO_img4883.tif',
#  'AOI_1_RIO_img4884.tif',
#  'AOI_1_RIO_img4885.tif',
#  'AOI_1_RIO_img4886.tif',
#  'AOI_1_RIO_img4887.tif',
#  'AOI_1_RIO_img4888.tif',
#  'AOI_1_RIO_img4889.tif',
#  'AOI_1_RIO_img5030.tif',
#  'AOI_1_RIO_img5031.tif',
#  'AOI_1_RIO_img5032.tif',
#  'AOI_1_RIO_img5033.tif',
#  'AOI_1_RIO_img5034.tif',
#  'AOI_1_RIO_img5035.tif',
#  'AOI_1_RIO_img5036.tif',
#  'AOI_1_RIO_img5037.tif',
#  'AOI_1_RIO_img5038.tif',
#  'AOI_1_RIO_img5039.tif',
#  'AOI_1_RIO_img504.tif',
#  'AOI_1_RIO_img5040.tif',
#  'AOI_1_RIO_img5041.tif',
#  'AOI_1_RIO_img5042.tif',
#  'AOI_1_RIO_img5043.tif',
#  'AOI_1_RIO_img5060.tif',
#  'AOI_1_RIO_img5061.tif',
#  'AOI_1_RIO_img5062.tif',
#  'AOI_1_RIO_img5063.tif',
#  'AOI_1_RIO_img5064.tif',
#  'AOI_1_RIO_img5065.tif',
#  'AOI_1_RIO_img5066.tif',
#  'AOI_1_RIO_img5067.tif',
#  'AOI_1_RIO_img5068.tif',
#  'AOI_1_RIO_img5069.tif',
#  'AOI_1_RIO_img5710.tif',
#  'AOI_1_RIO_img5711.tif',
#  'AOI_1_RIO_img5712.tif',
#  'AOI_1_RIO_img5713.tif',
#  'AOI_1_RIO_img5714.tif',
#  'AOI_1_RIO_img5715.tif',
#  'AOI_1_RIO_img5716.tif',
#  'AOI_1_RIO_img5717.tif',
#  'AOI_1_RIO_img5718.tif',
#  'AOI_1_RIO_img5719.tif',
#  'AOI_1_RIO_img572.tif',
#  'AOI_1_RIO_img5720.tif',
#  'AOI_1_RIO_img5721.tif',
#  'AOI_1_RIO_img5722.tif',
#  'AOI_1_RIO_img5723.tif',
#  'AOI_1_RIO_img5390.tif',
#  'AOI_1_RIO_img5391.tif',
#  'AOI_1_RIO_img5392.tif',
#  'AOI_1_RIO_img5393.tif',
#  'AOI_1_RIO_img5394.tif',
#  'AOI_1_RIO_img5395.tif',
#  'AOI_1_RIO_img5396.tif',
#  'AOI_1_RIO_img5397.tif',
#  'AOI_1_RIO_img5398.tif',
#  'AOI_1_RIO_img5399.tif',
#  'AOI_1_RIO_img341.tif',
#  'AOI_1_RIO_img343.tif',
#  'AOI_1_RIO_img3444.tif',
#  'AOI_1_RIO_img346.tif',
#  'AOI_1_RIO_img347.tif',
#  'AOI_1_RIO_img349.tif',
#  'AOI_1_RIO_img351.tif',
#  'AOI_1_RIO_img353.tif',
#  'AOI_1_RIO_img355.tif',
#  'AOI_1_RIO_img357.tif',
#  'AOI_1_RIO_img359.tif',
#  'AOI_1_RIO_img5780.tif',
#  'AOI_1_RIO_img5781.tif',
#  'AOI_1_RIO_img5782.tif',
#  'AOI_1_RIO_img5783.tif',
#  'AOI_1_RIO_img5784.tif',
#  'AOI_1_RIO_img5785.tif',
#  'AOI_1_RIO_img5786.tif',
#  'AOI_1_RIO_img5787.tif',
#  'AOI_1_RIO_img5788.tif',
#  'AOI_1_RIO_img5789.tif',
#  'AOI_1_RIO_img5930.tif',
#  'AOI_1_RIO_img5931.tif',
#  'AOI_1_RIO_img5932.tif',
#  'AOI_1_RIO_img5933.tif',
#  'AOI_1_RIO_img5934.tif',
#  'AOI_1_RIO_img5935.tif',
#  'AOI_1_RIO_img5936.tif',
#  'AOI_1_RIO_img5937.tif',
#  'AOI_1_RIO_img5938.tif',
#  'AOI_1_RIO_img5939.tif',
#  'AOI_1_RIO_img594.tif',
#  'AOI_1_RIO_img5940.tif',
#  'AOI_1_RIO_img5941.tif',
#  'AOI_1_RIO_img5942.tif',
#  'AOI_1_RIO_img5943.tif',
#  'AOI_1_RIO_img5990.tif',
#  'AOI_1_RIO_img5991.tif',
#  'AOI_1_RIO_img5992.tif',
#  'AOI_1_RIO_img5993.tif',
#  'AOI_1_RIO_img5994.tif',
#  'AOI_1_RIO_img5995.tif',
#  'AOI_1_RIO_img5996.tif',
#  'AOI_1_RIO_img5997.tif',
#  'AOI_1_RIO_img5998.tif',
#  'AOI_1_RIO_img5999.tif',
#  'AOI_1_RIO_img6230.tif',
#  'AOI_1_RIO_img6231.tif',
#  'AOI_1_RIO_img6232.tif',
#  'AOI_1_RIO_img6233.tif',
#  'AOI_1_RIO_img6234.tif',
#  'AOI_1_RIO_img6235.tif',
#  'AOI_1_RIO_img6236.tif',
#  'AOI_1_RIO_img6237.tif',
#  'AOI_1_RIO_img6238.tif',
#  'AOI_1_RIO_img6239.tif',
#  'AOI_1_RIO_img624.tif',
#  'AOI_1_RIO_img6240.tif',
#  'AOI_1_RIO_img6241.tif',
#  'AOI_1_RIO_img6242.tif',
#  'AOI_1_RIO_img6243.tif',
#  'AOI_1_RIO_img6380.tif',
#  'AOI_1_RIO_img6381.tif',
#  'AOI_1_RIO_img6382.tif',
#  'AOI_1_RIO_img6383.tif',
#  'AOI_1_RIO_img6384.tif',
#  'AOI_1_RIO_img6385.tif',
#  'AOI_1_RIO_img6386.tif',
#  'AOI_1_RIO_img6387.tif',
#  'AOI_1_RIO_img6388.tif',
#  'AOI_1_RIO_img6389.tif',
#  'AOI_1_RIO_img6530.tif',
#  'AOI_1_RIO_img6531.tif',
#  'AOI_1_RIO_img6532.tif',
#  'AOI_1_RIO_img6533.tif',
#  'AOI_1_RIO_img6534.tif',
#  'AOI_1_RIO_img6535.tif',
#  'AOI_1_RIO_img6536.tif',
#  'AOI_1_RIO_img6537.tif',
#  'AOI_1_RIO_img6538.tif',
#  'AOI_1_RIO_img6539.tif',
#  'AOI_1_RIO_img654.tif',
#  'AOI_1_RIO_img6540.tif',
#  'AOI_1_RIO_img6541.tif',
#  'AOI_1_RIO_img6542.tif',
#  'AOI_1_RIO_img6543.tif',
#  'AOI_1_RIO_img6610.tif',
#  'AOI_1_RIO_img6611.tif',
#  'AOI_1_RIO_img6612.tif',
#  'AOI_1_RIO_img6613.tif',
#  'AOI_1_RIO_img6614.tif',
#  'AOI_1_RIO_img6615.tif',
#  'AOI_1_RIO_img6616.tif',
#  'AOI_1_RIO_img6617.tif',
#  'AOI_1_RIO_img6618.tif',
#  'AOI_1_RIO_img6619.tif',
#  'AOI_1_RIO_img662.tif',
#  'AOI_1_RIO_img6620.tif',
#  'AOI_1_RIO_img6621.tif',
#  'AOI_1_RIO_img6622.tif',
#  'AOI_1_RIO_img6623.tif',
#  'AOI_1_RIO_img6820.tif',
#  'AOI_1_RIO_img6821.tif',
#  'AOI_1_RIO_img6822.tif',
#  'AOI_1_RIO_img6823.tif',
#  'AOI_1_RIO_img6824.tif',
#  'AOI_1_RIO_img6825.tif',
#  'AOI_1_RIO_img6826.tif',
#  'AOI_1_RIO_img6827.tif',
#  'AOI_1_RIO_img6828.tif',
#  'AOI_1_RIO_img6829.tif',
#  'AOI_1_RIO_img683.tif',
#  'AOI_1_RIO_img6830.tif',
#  'AOI_1_RIO_img6831.tif',
#  'AOI_1_RIO_img6832.tif',
#  'AOI_1_RIO_img6833.tif',
#  'AOI_1_RIO_img6834.tif',
#  'AOI_1_RIO_img6835.tif',
#  'AOI_1_RIO_img6836.tif',
#  'AOI_1_RIO_img6837.tif',
#  'AOI_1_RIO_img6838.tif',
#  'AOI_1_RIO_img6839.tif',
#  'AOI_1_RIO_img6920.tif',
#  'AOI_1_RIO_img6921.tif',
#  'AOI_1_RIO_img6922.tif',
#  'AOI_1_RIO_img6923.tif',
#  'AOI_1_RIO_img6924.tif',
#  'AOI_1_RIO_img6925.tif',
#  'AOI_1_RIO_img6926.tif',
#  'AOI_1_RIO_img6927.tif',
#  'AOI_1_RIO_img6928.tif',
#  'AOI_1_RIO_img6929.tif',
#  'AOI_1_RIO_img930.tif',
#  'AOI_1_RIO_img931.tif',
#  'AOI_1_RIO_img932.tif',
#  'AOI_1_RIO_img933.tif',
#  'AOI_1_RIO_img934.tif',
#  'AOI_1_RIO_img935.tif',
#  'AOI_1_RIO_img936.tif',
#  'AOI_1_RIO_img937.tif',
#  'AOI_1_RIO_img938.tif',
#  'AOI_1_RIO_img939.tif',
#  'AOI_1_RIO_img94.tif',
#  'AOI_1_RIO_img940.tif',
#  'AOI_1_RIO_img941.tif',
#  'AOI_1_RIO_img942.tif',
#  'AOI_1_RIO_img943.tif',
#  'AOI_1_RIO_img80.tif',
#  'AOI_1_RIO_img800.tif',
#  'AOI_1_RIO_img801.tif',
#  'AOI_1_RIO_img802.tif',
#  'AOI_1_RIO_img803.tif',
#  'AOI_1_RIO_img804.tif',
#  'AOI_1_RIO_img805.tif',
#  'AOI_1_RIO_img806.tif',
#  'AOI_1_RIO_img807.tif',
#  'AOI_1_RIO_img808.tif',
#  'AOI_1_RIO_img809.tif',
#  'AOI_1_RIO_img81.tif',
#  'AOI_1_RIO_img810.tif',
#  'AOI_1_RIO_img811.tif',
#  'AOI_1_RIO_img812.tif',
#  'AOI_1_RIO_img813.tif',
#  'AOI_1_RIO_img814.tif',
#  'AOI_1_RIO_img815.tif',
#  'AOI_1_RIO_img816.tif',
#  'AOI_1_RIO_img817.tif',
#  'AOI_1_RIO_img818.tif',
#  'AOI_1_RIO_img819.tif',
#  'AOI_1_RIO_img820.tif',
#  'AOI_1_RIO_img821.tif',
#  'AOI_1_RIO_img822.tif',
#  'AOI_1_RIO_img823.tif',
#  'AOI_1_RIO_img824.tif',
#  'AOI_1_RIO_img825.tif',
#  'AOI_1_RIO_img826.tif',
#  'AOI_1_RIO_img827.tif',
#  'AOI_1_RIO_img828.tif',
#  'AOI_1_RIO_img829.tif',
#  'AOI_1_RIO_img830.tif',
#  'AOI_1_RIO_img831.tif',
#  'AOI_1_RIO_img832.tif',
#  'AOI_1_RIO_img833.tif',
#  'AOI_1_RIO_img834.tif',
#  'AOI_1_RIO_img835.tif',
#  'AOI_1_RIO_img836.tif',
#  'AOI_1_RIO_img837.tif',
#  'AOI_1_RIO_img838.tif',
#  'AOI_1_RIO_img839.tif',
#  'AOI_1_RIO_img84.tif',
#  'AOI_1_RIO_img840.tif',
#  'AOI_1_RIO_img841.tif',
#  'AOI_1_RIO_img842.tif',
#  'AOI_1_RIO_img843.tif',
#  'AOI_1_RIO_img844.tif',
#  'AOI_1_RIO_img845.tif',
#  'AOI_1_RIO_img846.tif',
#  'AOI_1_RIO_img847.tif',
#  'AOI_1_RIO_img848.tif',
#  'AOI_1_RIO_img849.tif',
#  'AOI_1_RIO_img850.tif',
#  'AOI_1_RIO_img851.tif',
#  'AOI_1_RIO_img852.tif',
#  'AOI_1_RIO_img853.tif',
#  'AOI_1_RIO_img854.tif',
#  'AOI_1_RIO_img855.tif',
#  'AOI_1_RIO_img856.tif',
#  'AOI_1_RIO_img857.tif',
#  'AOI_1_RIO_img858.tif',
#  'AOI_1_RIO_img859.tif',
#  'AOI_1_RIO_img86.tif',
#  'AOI_1_RIO_img860.tif',
#  'AOI_1_RIO_img861.tif',
#  'AOI_1_RIO_img862.tif',
#  'AOI_1_RIO_img863.tif',
#  'AOI_1_RIO_img865.tif',
#  'AOI_1_RIO_img866.tif',
#  'AOI_1_RIO_img867.tif',
#  'AOI_1_RIO_img868.tif',
#  'AOI_1_RIO_img869.tif',
#  'AOI_1_RIO_img87.tif',
#  'AOI_1_RIO_img870.tif',
#  'AOI_1_RIO_img871.tif',
#  'AOI_1_RIO_img872.tif',
#  'AOI_1_RIO_img873.tif',
#  'AOI_1_RIO_img874.tif',
#  'AOI_1_RIO_img875.tif',
#  'AOI_1_RIO_img876.tif',
#  'AOI_1_RIO_img877.tif',
#  'AOI_1_RIO_img878.tif',
#  'AOI_1_RIO_img879.tif',
#  'AOI_1_RIO_img576.tif',
#  'AOI_1_RIO_img578.tif',
#  'AOI_1_RIO_img579.tif',
#  'AOI_1_RIO_img581.tif',
#  'AOI_1_RIO_img5824.tif',
#  'AOI_1_RIO_img584.tif',
#  'AOI_1_RIO_img585.tif',
#  'AOI_1_RIO_img587.tif',
#  'AOI_1_RIO_img589.tif',
#  'AOI_1_RIO_img591.tif',
#  'AOI_1_RIO_img593.tif',
#  'AOI_1_RIO_img5944.tif',
#  'AOI_1_RIO_img960.tif',
#  'AOI_1_RIO_img961.tif',
#  'AOI_1_RIO_img962.tif',
#  'AOI_1_RIO_img963.tif',
#  'AOI_1_RIO_img964.tif',
#  'AOI_1_RIO_img965.tif',
#  'AOI_1_RIO_img966.tif',
#  'AOI_1_RIO_img967.tif',
#  'AOI_1_RIO_img968.tif',
#  'AOI_1_RIO_img969.tif',
#  'AOI_1_RIO_img880.tif',
#  'AOI_1_RIO_img881.tif',
#  'AOI_1_RIO_img882.tif',
#  'AOI_1_RIO_img883.tif',
#  'AOI_1_RIO_img884.tif',
#  'AOI_1_RIO_img885.tif',
#  'AOI_1_RIO_img886.tif',
#  'AOI_1_RIO_img887.tif',
#  'AOI_1_RIO_img888.tif',
#  'AOI_1_RIO_img889.tif',
#  'AOI_1_RIO_img89.tif',
#  'AOI_1_RIO_img890.tif',
#  'AOI_1_RIO_img891.tif',
#  'AOI_1_RIO_img892.tif',
#  'AOI_1_RIO_img893.tif',
#  'AOI_1_RIO_img894.tif',
#  'AOI_1_RIO_img895.tif',
#  'AOI_1_RIO_img896.tif',
#  'AOI_1_RIO_img897.tif',
#  'AOI_1_RIO_img898.tif',
#  'AOI_1_RIO_img899.tif',
#  'AOI_1_RIO_img910.tif',
#  'AOI_1_RIO_img911.tif',
#  'AOI_1_RIO_img912.tif',
#  'AOI_1_RIO_img913.tif',
#  'AOI_1_RIO_img914.tif',
#  'AOI_1_RIO_img915.tif',
#  'AOI_1_RIO_img916.tif',
#  'AOI_1_RIO_img917.tif',
#  'AOI_1_RIO_img918.tif',
#  'AOI_1_RIO_img919.tif',
#  'AOI_1_RIO_img92.tif',
#  'AOI_1_RIO_img920.tif',
#  'AOI_1_RIO_img921.tif',
#  'AOI_1_RIO_img922.tif',
#  'AOI_1_RIO_img923.tif',
#  'AOI_1_RIO_img924.tif',
#  'AOI_1_RIO_img925.tif',
#  'AOI_1_RIO_img926.tif',
#  'AOI_1_RIO_img927.tif',
#  'AOI_1_RIO_img928.tif',
#  'AOI_1_RIO_img929.tif',
#  'AOI_1_RIO_img945.tif',
#  'AOI_1_RIO_img946.tif',
#  'AOI_1_RIO_img947.tif',
#  'AOI_1_RIO_img948.tif',
#  'AOI_1_RIO_img949.tif',
#  'AOI_1_RIO_img95.tif',
#  'AOI_1_RIO_img950.tif',
#  'AOI_1_RIO_img951.tif',
#  'AOI_1_RIO_img952.tif',
#  'AOI_1_RIO_img953.tif',
#  'AOI_1_RIO_img954.tif',
#  'AOI_1_RIO_img955.tif',
#  'AOI_1_RIO_img956.tif',
#  'AOI_1_RIO_img957.tif',
#  'AOI_1_RIO_img958.tif',
#  'AOI_1_RIO_img959.tif',
#  'AOI_1_RIO_img990.tif',
#  'AOI_1_RIO_img991.tif',
#  'AOI_1_RIO_img992.tif',
#  'AOI_1_RIO_img993.tif',
#  'AOI_1_RIO_img994.tif',
#  'AOI_1_RIO_img995.tif',
#  'AOI_1_RIO_img996.tif',
#  'AOI_1_RIO_img997.tif',
#  'AOI_1_RIO_img998.tif',
#  'AOI_1_RIO_img999.tif',
#  'AOI_1_RIO_img970.tif',
#  'AOI_1_RIO_img971.tif',
#  'AOI_1_RIO_img972.tif',
#  'AOI_1_RIO_img973.tif',
#  'AOI_1_RIO_img974.tif',
#  'AOI_1_RIO_img975.tif',
#  'AOI_1_RIO_img976.tif',
#  'AOI_1_RIO_img977.tif',
#  'AOI_1_RIO_img978.tif',
#  'AOI_1_RIO_img979.tif',
#  'AOI_1_RIO_img98.tif',
#  'AOI_1_RIO_img980.tif',
#  'AOI_1_RIO_img981.tif',
#  'AOI_1_RIO_img982.tif',
#  'AOI_1_RIO_img983.tif',
#  'AOI_1_RIO_img984.tif',
#  'AOI_1_RIO_img985.tif',
#  'AOI_1_RIO_img986.tif',
#  'AOI_1_RIO_img987.tif',
#  'AOI_1_RIO_img988.tif',
#  'AOI_1_RIO_img989.tif',
#  'AOI_1_RIO_img1080.tif',
#  'AOI_1_RIO_img1081.tif',
#  'AOI_1_RIO_img1082.tif',
#  'AOI_1_RIO_img1083.tif',
#  'AOI_1_RIO_img1084.tif',
#  'AOI_1_RIO_img1085.tif',
#  'AOI_1_RIO_img1086.tif',
#  'AOI_1_RIO_img1087.tif',
#  'AOI_1_RIO_img1088.tif',
#  'AOI_1_RIO_img1089.tif',
#  'AOI_1_RIO_img109.tif',
#  'AOI_1_RIO_img1090.tif',
#  'AOI_1_RIO_img1091.tif',
#  'AOI_1_RIO_img1092.tif',
#  'AOI_1_RIO_img1093.tif',
#  'AOI_1_RIO_img1094.tif',
#  'AOI_1_RIO_img1095.tif',
#  'AOI_1_RIO_img1096.tif',
#  'AOI_1_RIO_img1097.tif',
#  'AOI_1_RIO_img1098.tif',
#  'AOI_1_RIO_img1099.tif',
#  'AOI_1_RIO_img1020.tif',
#  'AOI_1_RIO_img1021.tif',
#  'AOI_1_RIO_img1022.tif',
#  'AOI_1_RIO_img1023.tif',
#  'AOI_1_RIO_img1024.tif',
#  'AOI_1_RIO_img1025.tif',
#  'AOI_1_RIO_img1026.tif',
#  'AOI_1_RIO_img1027.tif',
#  'AOI_1_RIO_img1028.tif',
#  'AOI_1_RIO_img1029.tif',
#  'AOI_1_RIO_img103.tif',
#  'AOI_1_RIO_img1030.tif',
#  'AOI_1_RIO_img1031.tif',
#  'AOI_1_RIO_img1032.tif',
#  'AOI_1_RIO_img1033.tif',
#  'AOI_1_RIO_img1034.tif',
#  'AOI_1_RIO_img1035.tif',
#  'AOI_1_RIO_img1036.tif',
#  'AOI_1_RIO_img1037.tif',
#  'AOI_1_RIO_img1038.tif',
#  'AOI_1_RIO_img1039.tif',
#  'AOI_1_RIO_img110.tif',
#  'AOI_1_RIO_img1100.tif',
#  'AOI_1_RIO_img1101.tif',
#  'AOI_1_RIO_img1102.tif',
#  'AOI_1_RIO_img1103.tif',
#  'AOI_1_RIO_img1104.tif',
#  'AOI_1_RIO_img1105.tif',
#  'AOI_1_RIO_img1106.tif',
#  'AOI_1_RIO_img1107.tif',
#  'AOI_1_RIO_img1108.tif',
#  'AOI_1_RIO_img1109.tif',
#  'AOI_1_RIO_img1130.tif',
#  'AOI_1_RIO_img1131.tif',
#  'AOI_1_RIO_img1132.tif',
#  'AOI_1_RIO_img1133.tif',
#  'AOI_1_RIO_img1134.tif',
#  'AOI_1_RIO_img1135.tif',
#  'AOI_1_RIO_img1136.tif',
#  'AOI_1_RIO_img1137.tif',
#  'AOI_1_RIO_img1138.tif',
#  'AOI_1_RIO_img1139.tif',
#  'AOI_1_RIO_img114.tif',
#  'AOI_1_RIO_img1140.tif',
#  'AOI_1_RIO_img1141.tif',
#  'AOI_1_RIO_img1142.tif',
#  'AOI_1_RIO_img1143.tif',
#  'AOI_1_RIO_img1365.tif',
#  'AOI_1_RIO_img1366.tif',
#  'AOI_1_RIO_img1367.tif',
#  'AOI_1_RIO_img1368.tif',
#  'AOI_1_RIO_img1369.tif',
#  'AOI_1_RIO_img137.tif',
#  'AOI_1_RIO_img1370.tif',
#  'AOI_1_RIO_img1371.tif',
#  'AOI_1_RIO_img1372.tif',
#  'AOI_1_RIO_img1373.tif',
#  'AOI_1_RIO_img1374.tif',
#  'AOI_1_RIO_img1375.tif',
#  'AOI_1_RIO_img1376.tif',
#  'AOI_1_RIO_img1377.tif',
#  'AOI_1_RIO_img1378.tif',
#  'AOI_1_RIO_img1379.tif',
#  'AOI_1_RIO_img1280.tif',
#  'AOI_1_RIO_img1281.tif',
#  'AOI_1_RIO_img1282.tif',
#  'AOI_1_RIO_img1283.tif',
#  'AOI_1_RIO_img1284.tif',
#  'AOI_1_RIO_img1285.tif',
#  'AOI_1_RIO_img1286.tif',
#  'AOI_1_RIO_img1287.tif',
#  'AOI_1_RIO_img1288.tif',
#  'AOI_1_RIO_img1289.tif',
#  'AOI_1_RIO_img129.tif',
#  'AOI_1_RIO_img1290.tif',
#  'AOI_1_RIO_img1291.tif',
#  'AOI_1_RIO_img1292.tif',
#  'AOI_1_RIO_img1293.tif',
#  'AOI_1_RIO_img1294.tif',
#  'AOI_1_RIO_img1295.tif',
#  'AOI_1_RIO_img1296.tif',
#  'AOI_1_RIO_img1297.tif',
#  'AOI_1_RIO_img1298.tif',
#  'AOI_1_RIO_img1299.tif',
#  'AOI_1_RIO_img1350.tif',
#  'AOI_1_RIO_img1351.tif',
#  'AOI_1_RIO_img1352.tif',
#  'AOI_1_RIO_img1353.tif',
#  'AOI_1_RIO_img1354.tif',
#  'AOI_1_RIO_img1355.tif',
#  'AOI_1_RIO_img1356.tif',
#  'AOI_1_RIO_img1357.tif',
#  'AOI_1_RIO_img1358.tif',
#  'AOI_1_RIO_img1359.tif',
#  'AOI_1_RIO_img136.tif',
#  'AOI_1_RIO_img1360.tif',
#  'AOI_1_RIO_img1361.tif',
#  'AOI_1_RIO_img1362.tif',
#  'AOI_1_RIO_img1363.tif',
#  'AOI_1_RIO_img1110.tif',
#  'AOI_1_RIO_img1111.tif',
#  'AOI_1_RIO_img1112.tif',
#  'AOI_1_RIO_img1113.tif',
#  'AOI_1_RIO_img1114.tif',
#  'AOI_1_RIO_img1115.tif',
#  'AOI_1_RIO_img1116.tif',
#  'AOI_1_RIO_img1117.tif',
#  'AOI_1_RIO_img1118.tif',
#  'AOI_1_RIO_img1119.tif',
#  'AOI_1_RIO_img112.tif',
#  'AOI_1_RIO_img1120.tif',
#  'AOI_1_RIO_img1121.tif',
#  'AOI_1_RIO_img1122.tif',
#  'AOI_1_RIO_img1123.tif',
#  'AOI_1_RIO_img1124.tif',
#  'AOI_1_RIO_img1125.tif',
#  'AOI_1_RIO_img1126.tif',
#  'AOI_1_RIO_img1127.tif',
#  'AOI_1_RIO_img1128.tif',
#  'AOI_1_RIO_img1129.tif',
#  'AOI_1_RIO_img1320.tif',
#  'AOI_1_RIO_img1321.tif',
#  'AOI_1_RIO_img1322.tif',
#  'AOI_1_RIO_img1323.tif',
#  'AOI_1_RIO_img1324.tif',
#  'AOI_1_RIO_img1325.tif',
#  'AOI_1_RIO_img1326.tif',
#  'AOI_1_RIO_img1327.tif',
#  'AOI_1_RIO_img1328.tif',
#  'AOI_1_RIO_img1329.tif',
#  'AOI_1_RIO_img1145.tif',
#  'AOI_1_RIO_img1146.tif',
#  'AOI_1_RIO_img1147.tif',
#  'AOI_1_RIO_img1148.tif',
#  'AOI_1_RIO_img1149.tif',
#  'AOI_1_RIO_img115.tif',
#  'AOI_1_RIO_img1150.tif',
#  'AOI_1_RIO_img1151.tif',
#  'AOI_1_RIO_img1152.tif',
#  'AOI_1_RIO_img1153.tif',
#  'AOI_1_RIO_img1154.tif',
#  'AOI_1_RIO_img1155.tif',
#  'AOI_1_RIO_img1156.tif',
#  'AOI_1_RIO_img1157.tif',
#  'AOI_1_RIO_img1158.tif',
#  'AOI_1_RIO_img1159.tif',
#  'AOI_1_RIO_img1450.tif',
#  'AOI_1_RIO_img1451.tif',
#  'AOI_1_RIO_img1452.tif',
#  'AOI_1_RIO_img1453.tif',
#  'AOI_1_RIO_img1454.tif',
#  'AOI_1_RIO_img1455.tif',
#  'AOI_1_RIO_img1456.tif',
#  'AOI_1_RIO_img1457.tif',
#  'AOI_1_RIO_img1458.tif',
#  'AOI_1_RIO_img1459.tif',
#  'AOI_1_RIO_img146.tif',
#  'AOI_1_RIO_img1460.tif',
#  'AOI_1_RIO_img1461.tif',
#  'AOI_1_RIO_img1462.tif',
#  'AOI_1_RIO_img1463.tif',
#  'AOI_1_RIO_img1160.tif',
#  'AOI_1_RIO_img1161.tif',
#  'AOI_1_RIO_img1162.tif',
#  'AOI_1_RIO_img1163.tif',
#  'AOI_1_RIO_img1164.tif',
#  'AOI_1_RIO_img1165.tif',
#  'AOI_1_RIO_img1166.tif',
#  'AOI_1_RIO_img1167.tif',
#  'AOI_1_RIO_img1168.tif',
#  'AOI_1_RIO_img1169.tif',
#  'AOI_1_RIO_img117.tif',
#  'AOI_1_RIO_img1170.tif',
#  'AOI_1_RIO_img1171.tif',
#  'AOI_1_RIO_img1172.tif',
#  'AOI_1_RIO_img1173.tif',
#  'AOI_1_RIO_img1174.tif',
#  'AOI_1_RIO_img1175.tif',
#  'AOI_1_RIO_img1176.tif',
#  'AOI_1_RIO_img1177.tif',
#  'AOI_1_RIO_img1178.tif',
#  'AOI_1_RIO_img1179.tif',
#  'AOI_1_RIO_img1180.tif',
#  'AOI_1_RIO_img1181.tif',
#  'AOI_1_RIO_img1182.tif',
#  'AOI_1_RIO_img1183.tif',
#  'AOI_1_RIO_img1184.tif',
#  'AOI_1_RIO_img1185.tif',
#  'AOI_1_RIO_img1186.tif',
#  'AOI_1_RIO_img1187.tif',
#  'AOI_1_RIO_img1188.tif',
#  'AOI_1_RIO_img1189.tif',
#  'AOI_1_RIO_img119.tif',
#  'AOI_1_RIO_img1190.tif',
#  ...]

# %%
#build_labels(path_3band, path_geojson, path_mask_img)

# %%
list_masks = get_list(path_mask_img)

list_3band = sorted(list_3band)
list_8band = sorted(list_8band)
list_3band_test = sorted(list_3band_test)
list_8band_test = sorted(list_8band_test)
list_masks = sorted(list_masks)

# %%
#  resize images
s = 224
N = len(list_3band)

def standardize(img):
    mean = img.mean()
    std = img.std()
    if(std != 0):
        img = (img - mean) / std
    return img    

def resize_images(list, path):
    images = []
    for i in tqdm(list):
        im = rio.open(path + i)
        im = im.read(out_shape=(s,s), resampling=Resampling.bilinear)
        if im.max()!=0:
            im = im / im.max()
        #im = standardize(im)
        images.append(im)
    return images

# # added by yoshioka 2021/06/05
# def resize_images_8band_to_4band(list, path):
#     images = []
#     for i in tqdm(list):
#         im = rio.open(path+i)
#         im = im.read(out_shape=(s,s), resampling=Resampling.bilinear)
#         if im.max()!=0:
#             im = im / im.max()
#         im = np.stack([im[1,:,:], im[2,:,:], im[4,:,:], im[6,:,:]], axis=0)
#         images.append(im)
#     return images

# added by yoshioka 2021/06/05
def resize_images_make_4band(list_3band, list_8band, three_band_path, eight_band_path):
    images = []
    for i, j in tqdm(zip(list_3band, list_8band)):
        im_3band = rio.open(three_band_path+i)
        im_8band = rio.open(eight_band_path+j)
        im_3band = im_3band.read(out_shape=(s,s), resampling=Resampling.bilinear)
        im_8band = im_8band.read(out_shape=(s,s), resampling=Resampling.bilinear)
        
        im_3band = np.array(im_3band)
        im_3band = im_3band / im_3band.max()
        
        im_8band = np.array(im_8band)
        im_8band = im_8band / im_8band.max()
        
        im_cat = np.stack([im_3band[0,:,:], im_3band[1,:,:], im_3band[2,:,:], im_8band[6,:,:]], axis=0)
        # --------------warning-----------------
        # The following normalization causes the images to be very dark!!
        if im_cat.max()!=0:
            im_cat = im_cat / im_cat.max()

        # im_cat = standardize(im_cat) # -> it causes wrong result
        images.append(im_cat)
    return images

# revised by yoshioka 2021/06/05
# to change the 3 band images to 4 band images
# by adding NIR in 8 band images
def get_batch_imgs(b, lists=[list_3band, list_8band], paths=[path_3band, path_8band]):
    out = np.zeros((N, b, s, s))
    if b == 8:
        for i, img in tqdm(enumerate(resize_images(lists[1], paths[1]))):
            out[i,:,:,:] = img
    elif b == 3:
        for i, img in tqdm(enumerate(resize_images(lists[0], paths[0]))):
            out[i,:,:,:] = img
    elif b == 4:
        for i, img in tqdm(enumerate(resize_images_make_4band(lists[0], lists[1], paths[0], paths[1]))):
            out[i,:,:,:] = img
    else:
        print("ERROR IN BAND NUMBER!")
    return out

def get_batch_masks(list, path):
    out = np.zeros((N, s, s))
    for i, img in tqdm(enumerate(resize_images(list, path))):
        out[i,:,:] = img
    return out

# def concat_band(list3, list8):
#     out = np.zeros((N, 11, s, s))
#     for i, (j, k) in tqdm(enumerate(zip(list3, list8))):
#         im = np.concatenate([j,k],0)
#         out[i,:,:,:] = im
#     return out

# %% [markdown]
# dataset / dataloader

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np
from torch.nn import functional as F
from torchvision import transforms
import albumentations as album
import random
import cv2

def preprocess(x, y):
    #x = x / MAX
    x = torch.from_numpy(x.astype('float32'))#.permute(1,2,0)
    if y is not None:
        y = torch.from_numpy(y.astype('float32'))#.permute(1,2,0)
        #y = F.one_hot(y, num_classes=2).permute(2,0,1)
    return x, y
    
def get_augmentation():
    border = cv2.BORDER_CONSTANT
    transform = [
        #album.Blur(),
        #album.OpticalDistortion(distort_limit=2, border_mode=border),
        #album.ElasticTransform(alpha=50, border_mode=border),
        #album.Rotate(limit=15, border_mode=border),
        album.ShiftScaleRotate(shift_limit=0.05, scale_limit=0.1, rotate_limit=0.5, border_mode=border),
        #album.ShiftScaleRotate(shift_limit=0, scale_limit=0.2, rotate_limit=0, border_mode=border),
        album.imgaug.transforms.IAAAffine(shear=10, mode='constant'),
        album.HorizontalFlip(p=0.5),
        album.VerticalFlip(p=0.5), 
        #album.RGBShift(r_shift_limit=10, g_shift_limit=10, b_shift_limit=20, always_apply=False, p=0.5),
    ]
    return album.Compose(transform, p=1.0)

def get_loader(dataset, batch_size, shuffle=False):
    return DataLoader(dataset, batch_size, shuffle)

class SatelliteDatasetFor4Band(Dataset):
    def __init__(self, img_3band_dir, img_8band_dir, mask_dir, augmentations, img_3band_ids, img_8band_ids, mask_ids, shape):
        super().__init__()
        self.img_3band_dir = img_3band_dir
        self.img_8band_dir = img_8band_dir
        self.mask_dir = mask_dir
        self.augmentations = augmentations
        self.img_3band_ids = img_3band_ids
        self.img_8band_ids = img_8band_ids
        self.mask_ids = mask_ids
        self.shape = shape
        assert len(img_3band_ids) == len(img_8band_ids), 'lengths of 3band and 8band datasets are not equal'
        assert len(img_3band_ids) == len(mask_ids), 'lengths of 3band and masks datasets are not equal'
        assert len(img_8band_ids) == len(mask_ids), 'lengths of 8band and masks datasets are not equal'
        self.data_size = len(img_3band_ids)
        
    def __len__(self):
        return self.data_size
        
    def __getitem__(self, index):
        img_3band_id, img_8band_id, mask_id = self.img_3band_ids[index], self.img_8band_ids[index], self.mask_ids[index]
        
        img_3band = rio.open(self.img_3band_dir + '/' + img_3band_id)
        img_8band = rio.open(self.img_8band_dir + '/' + img_8band_id)
        mask = rio.open(self.mask_dir + '/' + mask_id)
        
        img_3band = img_3band.read(out_shape=(self.shape, self.shape), resampling=Resampling.bilinear).astype('float32')
        img_8band = img_8band.read(out_shape=(self.shape, self.shape), resampling=Resampling.bilinear).astype('float32')
        mask = mask.read(out_shape=(self.shape, self.shape), resampling=Resampling.bilinear).astype('float32')
        
        img_3band = np.array(img_3band)
        if img_3band.max() != 0:
            img_3band = img_3band / img_3band.max()
        
        img_8band = np.array(img_8band)
        if img_8band.max() != 0:
            img_8band = img_8band / img_8band.max()
        
        img_4band = np.stack([img_8band[1,:,:], img_8band[2,:,:], img_8band[4,:,:], img_8band[6,:,:]], axis=0)
        
        if img_4band.max() != 0:
            img_4band = img_4band / img_4band.max()
        
        if mask.max() != 0:
            mask = mask / mask.max()
        
        if self.augmentations is not None:
            img_4band = img_4band.transpose(2,1,0) # change to (ch, W, H)
            mask = mask.transpose(2,1,0)
            aug = self.augmentations(image=img_4band, mask=mask)
            img, mask = aug['image'], aug['mask']
            img, mask = preprocess(img, mask)
            img = img.permute(2,1,0) # change to (H, W, ch)
            mask = mask.permute(2,1,0)
        else:
            img, mask = preprocess(img_4band, mask)
        return img, mask

# %%
building_satimg_dataset = SatelliteDatasetFor4Band(img_3band_dir=path_3band, img_8band_dir=path_8band, mask_dir=path_mask_img, augmentations=None, img_3band_ids=list_3band, img_8band_ids=list_8band, mask_ids=list_masks, shape=224)
print(building_satimg_dataset.__len__())
# Out:
# 6940

# %%
img, mask = building_satimg_dataset.__getitem__(1200)
img.shape, mask.shape
# Out:
# (torch.Size([4, 224, 224]), torch.Size([1, 224, 224]))

# %%
img = img.detach().numpy().transpose(1,2,0)
mask = mask.detach().numpy().squeeze()

img = np.stack([img[:,:,0], img[:,:,1], img[:,:,2]], axis=2)
print(img.shape)
fig, axes = plt.subplots(1,2,figsize=(15,6))
axes[0].imshow(img)
axes[1].imshow(mask)
# Out:
# (224, 224, 3)

# %%
building_satimg_dataset_augmentated = SatelliteDatasetFor4Band(img_3band_dir=path_3band, img_8band_dir=path_8band, mask_dir=path_mask_img, augmentations=get_augmentation(), img_3band_ids=list_3band, img_8band_ids=list_8band, mask_ids=list_masks, shape=224)

img, mask = building_satimg_dataset_augmentated.__getitem__(1200)
print(img.shape, mask.shape)

img = img.detach().numpy().transpose(1,2,0)
mask = mask.detach().numpy().squeeze()

img = np.stack([img[:,:,0], img[:,:,1], img[:,:,2]], axis=2)
print(img.shape)
fig, axes = plt.subplots(1,2,figsize=(15,6))
axes[0].imshow(img)
axes[1].imshow(mask)
# Out:
# torch.Size([4, 224, 224]) torch.Size([1, 224, 224])
# (224, 224, 3)
# /opt/conda/lib/python3.7/site-packages/albumentations/imgaug/transforms.py:337: FutureWarning: This IAAAffine is deprecated. Please use Affine instead
#   warnings.warn("This IAAAffine is deprecated. Please use Affine instead", FutureWarning)

# %% [markdown]
# albumentations test

# %%
img = rio.open('../building_detection_data/3band_train/3band/3band_AOI_1_RIO_img3745.tif')
data = img.read(out_shape=(448, 448), resampling=Resampling.bilinear)

data = data.transpose(1,2,0)
if data.max()!= 0:
    data = data / data.max()
print(data.shape, type(data))

transform = album.Compose([
    album.VerticalFlip(p=0.5),
    album.HorizontalFlip(p=0.5),
    album.GaussianBlur(),
    #album.imgaug.transforms.IAAAffine(shear=10, mode='constant'),
    # Methods that transform colors cannot be applied to 4band?
], p=0.5)

transformed = transform(image=data)
transformed_img = transformed["image"]
img = np.array(transformed_img)
plt.imshow(img) # album works fine.
# Out:
# (448, 448, 3) <class 'numpy.ndarray'>

# %%
img = img.transpose(2,1,0)
print(img.shape)
img = img.transpose(1,2,0)
print(img.shape)
# Out:
# (3, 448, 448)
# (448, 448, 3)

# %% [markdown]
# concatnate dataset

# %%
img, mask = building_satimg_dataset_augmentated.__getitem__(1202)
print(img.shape, mask.shape)

img = img.detach().numpy().transpose(1,2,0)
mask = mask.detach().numpy().squeeze()

img = np.stack([img[:,:,0], img[:,:,1], img[:,:,2]], axis=2)
print(img.shape)
fig, axes = plt.subplots(1,2,figsize=(15,6))
axes[0].imshow(img)
axes[1].imshow(mask)
# Out:
# torch.Size([4, 224, 224]) torch.Size([1, 224, 224])
# (224, 224, 3)

# %%
from torch.utils.data.dataset import ConcatDataset
building_satimg_dataset_concatnated = ConcatDataset([building_satimg_dataset, building_satimg_dataset_augmentated])
print(building_satimg_dataset_concatnated.__len__())
# Out:
# 13880

# %%
from torch.utils.data.dataset import Subset

n_samples = len(building_satimg_dataset_concatnated)
train_size = int(n_samples * 0.8)

train_subset_indices = list(range(0, train_size))
val_subset_indices = list(range(train_size,n_samples))

train_dataset = Subset(building_satimg_dataset_concatnated, train_subset_indices)
val_dataset = Subset(building_satimg_dataset_concatnated, val_subset_indices)

train_4b_loader = get_loader(dataset=train_dataset, batch_size=16, shuffle=True)
val_4b_loader = get_loader(dataset=val_dataset, batch_size=1, shuffle=False)

# %%
#  configure
criterion = nn.BCELoss()

#  Metrics
epsilon = 1e-6
def IoU(pred, mask):
    pred = pred.cpu().numpy().astype(int)
    mask = mask.cpu().numpy().astype(int)
    intersection = (pred & mask).sum()
    union = (pred | mask).sum()
    out = (intersection + epsilon) / (union + epsilon)
    return out

# %%
# Early stopping
# https://github.com/Bjarten/early-stopping-pytorch
class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""
    def __init__(self, patience=7, verbose=False):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf

    def __call__(self, val_loss, model):

        
        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
                #self.counter = 0
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), 'checkpoint.pt')
        self.val_loss_min = val_loss

# %%
#  U-Net Model
#  https://github.com/usuyama/pytorch-unet/blob/master/pytorch_unet.py

theta = (0.005, 0.01, 0.015, 0.02, 0.025) # change detectionにおける閾値

def double_conv(in_channels, out_channels, stride, padding):
    return nn.Sequential(
        nn.Conv2d(in_channels=in_channels, out_channels=out_channels, kernel_size=3, stride=stride, padding=padding),
        nn.ReLU(inplace=True),
        nn.Conv2d(out_channels, out_channels, 3, padding=1),
        nn.ReLU(inplace=True)
    )

class UNet(nn.Module):
    def __init__(self, input_ch, n_class):
        super().__init__()
        
        self.dconv_down1 = double_conv(input_ch, 64, 1, 1)
        self.dconv_down2 = double_conv(64, 128, 1, 1)
        self.dconv_down3 = double_conv(128, 256, 1, 1)
        self.dconv_down4 = double_conv(256, 512, 1, 1)
        self.dconv_down5 = double_conv(512,1024, 1, 1)
        self.maxpool = nn.MaxPool2d(2)
        self.upsample = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        self.dconv_up4 = double_conv(512+1024, 512, 1, 1) # stride=2,padding=0は失敗
        self.dconv_up3 = double_conv(256+512, 256, 1, 1)
        self.dconv_up2 = double_conv(128+256, 128, 1, 1)
        self.dconv_up1 = double_conv(64+128, 64, 1, 1)
        self.conv_last = nn.Conv2d(64, n_class, 1)
        #self.mode = mode # 1: 1枚の画像に対して学習/推論, 2: 2枚の画像を用いてDIを作成
        
    def forward(self, *x):
        if len(x) == 1:
            x = x[0]
            conv1 = self.dconv_down1(x)
            x = self.maxpool(conv1)
            conv2 = self.dconv_down2(x)
            x = self.maxpool(conv2)
            conv3 = self.dconv_down3(x)
            x = self.maxpool(conv3)
            conv4 = self.dconv_down4(x)
            x = self.maxpool(conv4)
            conv5 = self.dconv_down5(x)
            x = self.upsample(conv5)
            x = torch.cat([x, conv4], dim=1)
            x = self.dconv_up4(x)
            x = self.upsample(x)
            x = torch.cat([x, conv3], dim=1)
            x = self.dconv_up3(x)
            x = self.upsample(x)
            x = torch.cat([x, conv2], dim=1)
            x = self.dconv_up2(x)
            x = self.upsample(x)
            x = torch.cat([x, conv1], dim=1)
            x = self.dconv_up1(x)
            out = self.conv_last(x)
            return out
        elif len(x) == 2:
            # conv for each image
            conv_1 = self.dconv_down1(x[0].to(device))
            conv_2 = self.dconv_down1(x[1].to(device))
            # threshold processing
            di1 = abs(conv_1 - conv_2)
            di1 = torch.where(di1 <= theta[0], torch.tensor(0.).to(device), conv_2.to(device))
            # pooling
            x_1 = self.maxpool(conv_1)
            x_2 = self.maxpool(conv_2)
            # conv for each image
            conv_1 = self.dconv_down2(x_1)
            conv_2 = self.dconv_down2(x_2)
            # threshold processing
            di2 = abs(conv_1 - conv_2)
            di2 = torch.where(di2 <= theta[1], torch.tensor(0.).to(device), conv_2.to(device))
            # pooling
            x_1 = self.maxpool(conv_1)
            x_2 = self.maxpool(conv_2)
            # conv for each image
            conv_1 = self.dconv_down3(x_1)
            conv_2 = self.dconv_down3(x_2)
            # threshold processing
            di3 = abs(conv_1 - conv_2)
            di3 = torch.where(di3 <= theta[2], torch.tensor(0.).to(device), conv_2.to(device))
            # pooling
            x_1 = self.maxpool(conv_1)
            x_2 = self.maxpool(conv_2)
            # conv for each image
            conv_1 = self.dconv_down4(x_1)
            conv_2 = self.dconv_down4(x_2)
            # threshold processing
            di4 = abs(conv_1 - conv_2)
            di4 = torch.where(di4 <= theta[3], torch.tensor(0.).to(device), conv_2.to(device))
            # pooling
            x_1 = self.maxpool(conv_1)
            x_2 = self.maxpool(conv_2)
            # conv for each image
            conv_1 = self.dconv_down5(x_1)
            conv_2 = self.dconv_down5(x_2)
            # threshold processing
            di5 = abs(conv_1 - conv_2)
            di5 = torch.where(di5 <= theta[4], torch.tensor(0.).to(device), conv_2.to(device))
            
            # convolutionのみパラメータを有する
            # convolution層は全て名称が存在（区別可能） -> 学習したパラメータはメソッド（dconv_down1とか）とセットで保存されているはず
            # len=2でネットワーク構造が変化しても, 当該メソッドは利用可能と判断される
            
            # decode
            x = self.upsample(di5)
            x = torch.cat([x, di4], dim=1)
            x = self.dconv_up4(x)
            x = self.upsample(x)
            x = torch.cat([x, di3], dim=1)
            x = self.dconv_up3(x)
            x = self.upsample(x)
            x = torch.cat([x, di2], dim=1)
            x = self.dconv_up2(x)
            x = self.upsample(x)
            x = torch.cat([x, di1], dim=1)
            x = self.dconv_up1(x)
            out = self.conv_last(x)
            return out
            
model = UNet(4, 1)
model = model.to(device)  

from torchsummary import summary
summary(model, (4, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 224, 224]           2,368
#               ReLU-2         [-1, 64, 224, 224]               0
#             Conv2d-3         [-1, 64, 224, 224]          36,928
#               ReLU-4         [-1, 64, 224, 224]               0
#          MaxPool2d-5         [-1, 64, 112, 112]               0
#             Conv2d-6        [-1, 128, 112, 112]          73,856
#               ReLU-7        [-1, 128, 112, 112]               0
#             Conv2d-8        [-1, 128, 112, 112]         147,584
#               ReLU-9        [-1, 128, 112, 112]               0
#         MaxPool2d-10          [-1, 128, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]         295,168
#              ReLU-12          [-1, 256, 56, 56]               0
#            Conv2d-13          [-1, 256, 56, 56]         590,080
#              ReLU-14          [-1, 256, 56, 56]               0
#         MaxPool2d-15          [-1, 256, 28, 28]               0
#            Conv2d-16          [-1, 512, 28, 28]       1,180,160
#              ReLU-17          [-1, 512, 28, 28]               0
#            Conv2d-18          [-1, 512, 28, 28]       2,359,808
#              ReLU-19          [-1, 512, 28, 28]               0
#         MaxPool2d-20          [-1, 512, 14, 14]               0
#            Conv2d-21         [-1, 1024, 14, 14]       4,719,616
#              ReLU-22         [-1, 1024, 14, 14]               0
#            Conv2d-23         [-1, 1024, 14, 14]       9,438,208
#              ReLU-24         [-1, 1024, 14, 14]               0
#          Upsample-25         [-1, 1024, 28, 28]               0
#            Conv2d-26          [-1, 512, 28, 28]       7,078,400
#              ReLU-27          [-1, 512, 28, 28]               0
#            Conv2d-28          [-1, 512, 28, 28]       2,359,808
#              ReLU-29          [-1, 512, 28, 28]               0
#          Upsample-30          [-1, 512, 56, 56]               0
#            Conv2d-31          [-1, 256, 56, 56]       1,769,728
#              ReLU-32          [-1, 256, 56, 56]               0
#            Conv2d-33          [-1, 256, 56, 56]         590,080
#              ReLU-34          [-1, 256, 56, 56]               0
#          Upsample-35        [-1, 256, 112, 112]               0
#            Conv2d-36        [-1, 128, 112, 112]         442,496
#              ReLU-37        [-1, 128, 112, 112]               0
#            Conv2d-38        [-1, 128, 112, 112]         147,584
#              ReLU-39        [-1, 128, 112, 112]               0
#          Upsample-40        [-1, 128, 224, 224]               0
#            Conv2d-41         [-1, 64, 224, 224]         110,656
#              ReLU-42         [-1, 64, 224, 224]               0
#            Conv2d-43         [-1, 64, 224, 224]          36,928
#              ReLU-44         [-1, 64, 224, 224]               0
#            Conv2d-45          [-1, 1, 224, 224]              65
# ================================================================
# Total params: 31,379,521
# Trainable params: 31,379,521
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.77
# Forward/backward pass size (MB): 477.37
# Params size (MB): 119.70
# Estimated Total Size (MB): 597.84
# ----------------------------------------------------------------

# %%
def func(*arg):
    return arg

x = func([1,2,3], [2,3,4])
print(len(x))
# Out:
# 2

# %%
x = torch.randn(3,2)
y = torch.ones(3,2)
print(x)
print(y)
print(x-y)
print(abs(x-y))
# Out:
# tensor([[ 1.4643, -0.2717],
#         [ 1.7509,  2.0584],
#         [ 0.0134,  0.1140]])
# tensor([[1., 1.],
#         [1., 1.],
#         [1., 1.]])
# tensor([[ 0.4643, -1.2717],
#         [ 0.7509,  1.0584],
#         [-0.9866, -0.8860]])
# tensor([[0.4643, 1.2717],
#         [0.7509, 1.0584],
#         [0.9866, 0.8860]])

# %% [markdown]
# training

# %%
#  train 
def train(model, optimizer, train_loader, val_loader, epochs):
    model.train()
    log = {"train_loss":[], "train_iou":[], "val_loss":[], "val_iou":[]}
    early_stopping = EarlyStopping(5, True)
    for epoch in tqdm(range(epochs)):
        epoch_loss = 0
        epoch_iou = 0
        for data, mask in train_loader:
            data, mask = data.to(device), mask.to(device)
            mask = mask.view(-1)
            out = model(data)
            out = torch.sigmoid(out)
            out = out.view(-1)
            loss = criterion(out, mask)
            pred = torch.where(out >= 0.5, torch.tensor(1.).to(device), torch.tensor(0.).to(device))
            iou = IoU(pred, mask)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            epoch_loss += float(loss.item())
            epoch_iou += float(iou.item())
        epoch_loss = epoch_loss / len(train_loader)
        epoch_iou = epoch_iou / len(train_loader)
        log["train_loss"].append(epoch_loss)
        log["train_iou"].append(epoch_iou)
        
        # validation
        val_loss = 0
        val_iou = 0
        with torch.no_grad():
            for data, mask in val_loader:
                data, mask = data.to(device), mask.to(device)
                mask = mask.view(-1)
                out = model(data)
                out = torch.sigmoid(out)
                out = out.view(-1)
                loss = criterion(out, mask)
                pred = torch.where(out >= 0.5, torch.tensor(1.).to(device), torch.tensor(0.).to(device))
                iou = IoU(pred, mask)
                val_loss += float(loss.item())
                val_iou += float(iou.item())
        val_loss = val_loss / len(val_loader)
        val_iou = val_iou / len(val_loader)
        log["val_loss"].append(val_loss)
        log["val_iou"].append(val_iou)
        print('epoch{}:終了  train_loss={}, train_iou={}, val_loss={}, val_iou={}\n'.format(epoch, epoch_loss, epoch_iou, val_loss, val_iou))
        early_stopping(val_loss, model)
        if early_stopping.early_stop:
            print("Early stopping")
            break
        
    
    fig = plt.figure(figsize=(12,6))
    plt.subplot(1,2,1)
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.plot(log["train_loss"], color='orangered', label='train')
    plt.plot(log["val_loss"], color='cyan', label='val')
    plt.legend(loc=0)
    
    plt.subplot(1,2,2)
    plt.xlabel('epoch')
    plt.ylabel('iou')
    plt.plot(log["train_iou"], color='orangered', label='train')
    plt.plot(log["val_iou"], color='cyan', label='val')
    plt.legend(loc=0)
    plt.show()
    fig.savefig("img/train_log.png")
    return log
    
        
#  test
threshold = 0.5
def test(model, load_test):
    model.load_state_dict(torch.load('checkpoint.pt'))
    model.eval()
    test_loss = 0
    test_iou = 0
    for data, mask in tqdm(load_test):
        data, mask = data.to(device), mask.to(device)
        mask = mask.view(-1)
        out = model(data)
        out = torch.sigmoid(out)
        out = out.view(-1)
        loss = criterion(out, mask)
        test_loss += float(loss.item())
        pred = torch.where(out >= 0.5, torch.tensor(1.).to(device), torch.tensor(0.).to(device))
        #pred_np = pred.to('cpu').detach().numpy().copy().reshape(224,224)
        #pred = morphology.binary_closing(pred_np, morphology.diamond(1)).astype(np.uint8)
        #pred = torch.from_numpy(pred).view(-1).to(device)
        iou = IoU(pred, mask)
        test_iou += float(iou.item())
    test_loss = test_loss/len(load_test)
    test_iou = test_iou/len(load_test)
    print('テスト終了  test_loss={},  test_iou={}'.format(test_loss, test_iou))

# %%
#  execute train
model = UNet(4, 1)
model = model.to(device)
optimizer = optim.Adam(model.parameters(), lr=0.0001)
log = {"train_loss":[], "train_iou":[], "val_loss":[], "val_iou":[]} 
log = train(model, optimizer, train_4b_loader, val_4b_loader, 30)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# epoch0:終了  train_loss=0.22023489236595478, train_iou=0.241556314278822, val_loss=0.1293286614262003, val_iou=0.5856435050818634
#
# Validation loss decreased (inf --> 0.129329).  Saving model ...
#   3%|▎         | 1/30 [11:24<5:30:51, 684.53s/it]
# epoch1:終了  train_loss=0.15429079318177547, train_iou=0.5115483633274467, val_loss=0.11538960971035314, val_iou=0.5962087626135513
#
# Validation loss decreased (0.129329 --> 0.115390).  Saving model ...
#   7%|▋         | 2/30 [23:04<5:23:34, 693.39s/it]
# epoch2:終了  train_loss=0.1413249796073916, train_iou=0.5537775202031935, val_loss=0.10817079788229335, val_iou=0.6469495695282489
#
# Validation loss decreased (0.115390 --> 0.108171).  Saving model ...
#  10%|█         | 3/30 [34:46<5:13:48, 697.34s/it]
# epoch3:終了  train_loss=0.13623365273253632, train_iou=0.5701728247523425, val_loss=0.10191365702208355, val_iou=0.6607563394504256
#
# Validation loss decreased (0.108171 --> 0.101914).  Saving model ...
#  13%|█▎        | 4/30 [46:26<5:02:42, 698.55s/it]
# epoch4:終了  train_loss=0.13034662567830566, train_iou=0.5861346334444949, val_loss=0.10131005929068017, val_iou=0.6641872987136488
#
# Validation loss decreased (0.101914 --> 0.101310).  Saving model ...
#  17%|█▋        | 5/30 [58:06<4:51:12, 698.90s/it]
# epoch5:終了  train_loss=0.12594119442213508, train_iou=0.5982718341273527, val_loss=0.09876219898018546, val_iou=0.6610856181911979
#
# Validation loss decreased (0.101310 --> 0.098762).  Saving model ...
#  23%|██▎       | 7/30 [1:21:21<4:27:36, 698.09s/it]
# epoch6:終了  train_loss=0.12582979226211133, train_iou=0.5972810837808675, val_loss=0.1014031456228636, val_iou=0.6659046036081546
#
# EarlyStopping counter: 1 out of 5
# epoch7:終了  train_loss=0.12334361360797536, train_iou=0.6046599576749812, val_loss=0.095168583628771, val_iou=0.6833498164527392
#
# Validation loss decreased (0.098762 --> 0.095169).  Saving model ...
#  30%|███       | 9/30 [1:44:36<4:04:09, 697.58s/it]
# epoch8:終了  train_loss=0.12055623951376086, train_iou=0.6110332383286705, val_loss=0.0995613168696649, val_iou=0.6788714466207559
#
# EarlyStopping counter: 1 out of 5
# epoch9:終了  train_loss=0.1199194766199941, train_iou=0.6138709158344247, val_loss=0.09101541473226901, val_iou=0.685761863911035
#
# Validation loss decreased (0.095169 --> 0.091015).  Saving model ...
#  33%|███▎      | 10/30 [1:56:11<3:52:18, 696.93s/it]
# epoch10:終了  train_loss=0.11710710353043564, train_iou=0.6214401904885728, val_loss=0.0908437142083256, val_iou=0.6941834303708978
#
# Validation loss decreased (0.091015 --> 0.090844).  Saving model ...
#  40%|████      | 12/30 [2:19:21<3:28:46, 695.90s/it]
# epoch11:終了  train_loss=0.11541814429776727, train_iou=0.6243500962449346, val_loss=0.0965053282664853, val_iou=0.6666355650776415
#
# EarlyStopping counter: 1 out of 5
# epoch12:終了  train_loss=0.1169754594526863, train_iou=0.6220799670264497, val_loss=0.0895709783996388, val_iou=0.6955043337349635
#
# Validation loss decreased (0.090844 --> 0.089571).  Saving model ...
#  43%|████▎     | 13/30 [2:30:56<3:17:05, 695.61s/it]
# epoch13:終了  train_loss=0.11533526546705611, train_iou=0.6263777509070311, val_loss=0.08888603260665227, val_iou=0.7047170702924945
#
# Validation loss decreased (0.089571 --> 0.088886).  Saving model ...
#  50%|█████     | 15/30 [2:54:02<2:53:34, 694.30s/it]
# epoch14:終了  train_loss=0.11389069060824532, train_iou=0.6309305428717534, val_loss=0.09021865401756476, val_iou=0.6911533363348988
#
# EarlyStopping counter: 1 out of 5
#  53%|█████▎    | 16/30 [3:05:36<2:41:57, 694.12s/it]
# epoch15:終了  train_loss=0.11187690394455486, train_iou=0.6351498913757462, val_loss=0.08905269934414828, val_iou=0.7010471991283136
#
# EarlyStopping counter: 2 out of 5
# epoch16:終了  train_loss=0.11103374176854616, train_iou=0.6368995294794958, val_loss=0.08418057855501627, val_iou=0.7110522741678728
#
# Validation loss decreased (0.088886 --> 0.084181).  Saving model ...
#  60%|██████    | 18/30 [3:28:40<2:18:35, 692.93s/it]
# epoch17:終了  train_loss=0.11031653104290924, train_iou=0.639293265841832, val_loss=0.08498453716857175, val_iou=0.701872796364708
#
# EarlyStopping counter: 1 out of 5
#  63%|██████▎   | 19/30 [3:40:11<2:06:57, 692.48s/it]
# epoch18:終了  train_loss=0.11152234182878255, train_iou=0.6365248396583512, val_loss=0.08429097263179701, val_iou=0.7121890895263886
#
# EarlyStopping counter: 2 out of 5
#  67%|██████▋   | 20/30 [3:51:44<1:55:24, 692.49s/it]
# epoch19:終了  train_loss=0.10834379736280407, train_iou=0.6442027260249039, val_loss=0.08431683261570594, val_iou=0.714943975380612
#
# EarlyStopping counter: 3 out of 5
#  70%|███████   | 21/30 [4:03:15<1:43:48, 692.05s/it]
# epoch20:終了  train_loss=0.10828699560913792, train_iou=0.6446928254276446, val_loss=0.08573404470744517, val_iou=0.7067924389544837
#
# EarlyStopping counter: 4 out of 5
#  70%|███████   | 21/30 [4:14:47<1:49:11, 727.97s/it]
# epoch21:終了  train_loss=0.10751904408858086, train_iou=0.6466673269649964, val_loss=0.08592957363791186, val_iou=0.7145570014617632
#
# EarlyStopping counter: 5 out of 5
# Early stopping
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-32-15e2f53a0000> in <module>
#       4 optimizer = optim.Adam(model.parameters(), lr=0.0001)
#       5 log = {"train_loss":[], "train_iou":[], "val_loss":[], "val_iou":[]}
# ----> 6 log = train(model, optimizer, train_4b_loader, val_4b_loader, 30)
#
# <ipython-input-31-37012394ea23> in train(model, optimizer, train_loader, val_loader, epochs)
#      67     plt.legend(loc=0)
#      68     plt.show()
# ---> 69     fig.savefig("img/train_log.png")
#      70     return log
#      71
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2215                     orientation=orientation,
#    2216                     bbox_inches_restore=_bbox_inches_restore,
# -> 2217                     **kwargs)
#    2218             finally:
#    2219                 if bbox_inches and restore_bbox:
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1637             kwargs.pop(arg)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#    1641     return wrapper
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     510         mpl.image.imsave(
#     511             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
# --> 512             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#     513
#     514     def print_to_buffer(self):
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1609         pil_kwargs.setdefault("format", format)
#    1610         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1611         image.save(fname, **pil_kwargs)
#    1612
#    1613
#
# /opt/conda/lib/python3.7/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2167                 fp = builtins.open(filename, "r+b")
#    2168             else:
# -> 2169                 fp = builtins.open(filename, "w+b")
#    2170
#    2171         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'img/train_log.png'

# %%
loaded_model = UNet(4,1)
loaded_model = loaded_model.to(device)
loaded_model.load_state_dict(torch.load('checkpoint.pt'))

summary(model, (4, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 224, 224]           2,368
#               ReLU-2         [-1, 64, 224, 224]               0
#             Conv2d-3         [-1, 64, 224, 224]          36,928
#               ReLU-4         [-1, 64, 224, 224]               0
#          MaxPool2d-5         [-1, 64, 112, 112]               0
#             Conv2d-6        [-1, 128, 112, 112]          73,856
#               ReLU-7        [-1, 128, 112, 112]               0
#             Conv2d-8        [-1, 128, 112, 112]         147,584
#               ReLU-9        [-1, 128, 112, 112]               0
#         MaxPool2d-10          [-1, 128, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]         295,168
#              ReLU-12          [-1, 256, 56, 56]               0
#            Conv2d-13          [-1, 256, 56, 56]         590,080
#              ReLU-14          [-1, 256, 56, 56]               0
#         MaxPool2d-15          [-1, 256, 28, 28]               0
#            Conv2d-16          [-1, 512, 28, 28]       1,180,160
#              ReLU-17          [-1, 512, 28, 28]               0
#            Conv2d-18          [-1, 512, 28, 28]       2,359,808
#              ReLU-19          [-1, 512, 28, 28]               0
#         MaxPool2d-20          [-1, 512, 14, 14]               0
#            Conv2d-21         [-1, 1024, 14, 14]       4,719,616
#              ReLU-22         [-1, 1024, 14, 14]               0
#            Conv2d-23         [-1, 1024, 14, 14]       9,438,208
#              ReLU-24         [-1, 1024, 14, 14]               0
#          Upsample-25         [-1, 1024, 28, 28]               0
#            Conv2d-26          [-1, 512, 28, 28]       7,078,400
#              ReLU-27          [-1, 512, 28, 28]               0
#            Conv2d-28          [-1, 512, 28, 28]       2,359,808
#              ReLU-29          [-1, 512, 28, 28]               0
#          Upsample-30          [-1, 512, 56, 56]               0
#            Conv2d-31          [-1, 256, 56, 56]       1,769,728
#              ReLU-32          [-1, 256, 56, 56]               0
#            Conv2d-33          [-1, 256, 56, 56]         590,080
#              ReLU-34          [-1, 256, 56, 56]               0
#          Upsample-35        [-1, 256, 112, 112]               0
#            Conv2d-36        [-1, 128, 112, 112]         442,496
#              ReLU-37        [-1, 128, 112, 112]               0
#            Conv2d-38        [-1, 128, 112, 112]         147,584
#              ReLU-39        [-1, 128, 112, 112]               0
#          Upsample-40        [-1, 128, 224, 224]               0
#            Conv2d-41         [-1, 64, 224, 224]         110,656
#              ReLU-42         [-1, 64, 224, 224]               0
#            Conv2d-43         [-1, 64, 224, 224]          36,928
#              ReLU-44         [-1, 64, 224, 224]               0
#            Conv2d-45          [-1, 1, 224, 224]              65
# ================================================================
# Total params: 31,379,521
# Trainable params: 31,379,521
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.77
# Forward/backward pass size (MB): 477.37
# Params size (MB): 119.70
# Estimated Total Size (MB): 597.84
# ----------------------------------------------------------------

# %%
# one image and mask are extracted from validation dataset
data_iter = iter(val_4b_loader)
imgs, masks = data_iter.next()
img = imgs[0]
mask = masks[0]

# replace some area of img, mask with some area of img_for_crop, mask_for_crop
imgs, masks = data_iter.next()
img_for_crop = imgs[0]
mask_for_crop = masks[0]

# %%
img_for_pred = img.unsqueeze(0)
print(img_for_pred.shape)
# Out:
# torch.Size([1, 4, 224, 224])

# %%
pred = loaded_model(img_for_pred.to(device))
pred = pred.cpu().detach().numpy().squeeze()
pred = np.where(pred>=0.5, 1, 0)
plt.imshow(pred)

# %%
img = img.permute(1,2,0)

# %%
img_np = img.to('cpu').detach().numpy().copy()

# %%
mask = mask.to('cpu').detach().numpy().copy()

# %%
img_np_3band = np.stack([img_np[:,:,0], img_np[:,:,1], img_np[:,:,2]], axis=2)
mask_np_1band = np.squeeze(mask)
plt.figure(figsize=(12,12))
plt.subplot(1,3,1)
plt.imshow(img_np_3band)
plt.subplot(1,3,2)
plt.imshow(mask_np_1band)
plt.subplot(1,3,3)
plt.imshow(pred)

# %%
img_for_crop_np = img_for_crop.permute(1,2,0).to('cpu').detach().numpy().copy()
mask_for_crop_np = mask_for_crop.to('cpu').detach().numpy().copy()

img_for_crop_np_3band = np.stack([img_for_crop_np[:,:,0], img_for_crop_np[:,:,1], img_for_crop_np[:,:,2]], axis=2)
mask_for_crop_np_1band = np.squeeze(mask_for_crop_np)
plt.figure(figsize=(12,12))
plt.subplot(1,2,1)
plt.imshow(img_for_crop_np_3band)
plt.subplot(1,2,2)
plt.imshow(mask_for_crop_np_1band)

# %% [markdown]
# # Change Detection for SpaceNet dataset (building detection v1)

# %%
img_crop_area = img_for_crop_np_3band[50:75,50:75,:]
mask_crop_area = mask_for_crop_np_1band[50:75,50:75]

img_replaced_area = img_np_3band[50:75,50:75,:]
mask_replaced_area = mask_np_1band[50:75,50:75]

plt.figure(figsize=(12,12))
plt.subplot(2,2,1)
plt.imshow(img_replaced_area)
plt.subplot(2,2,2)
plt.imshow(mask_replaced_area)
plt.subplot(2,2,3)
plt.imshow(img_crop_area)
plt.subplot(2,2,4)
plt.imshow(mask_crop_area)

# %%
_img_np_3band = img_np_3band.copy()
_mask_np_1band = mask_np_1band.copy()

_img_np_3band[50:75,50:75,:] = img_crop_area
_mask_np_1band[50:75,50:75] = mask_crop_area

# %%
plt.figure(figsize=(12,12))
plt.subplot(1,2,1)
plt.imshow(_img_np_3band)
plt.subplot(1,2,2)
plt.imshow(_mask_np_1band)

# %%
# 4band ver
img_crop_area_np_4band = img_for_crop_np[50:75,50:75,:]

_img_np_4band = img_np.copy()
_img_np_4band[50:75,50:75,:] = img_crop_area_np_4band

_img_np_4band.shape

# %%
# confirm that some area of the 4band image is replaced
_img_np_3band_from_4band = np.stack([_img_np_4band[:,:,0], _img_np_4band[:,:,1], _img_np_4band[:,:,2]], axis=2)
plt.figure(figsize=(12,12))
plt.subplot(1,2,1)
plt.imshow(_img_np_3band_from_4band)
plt.subplot(1,2,2)
plt.imshow(_mask_np_1band)

# %%
img_replaced_tensor = torch.from_numpy(_img_np_4band.astype(np.float32)).clone()
print(img_replaced_tensor.shape)
img_replaced_tensor_permute = img_replaced_tensor.permute(2,0,1)
print(img_replaced_tensor_permute.shape)

# %%
#img_replaced_tensor_permute = img_replaced_tensor_permute.to(device)
print(img_replaced_tensor_permute.unsqueeze(0).shape)
pred = loaded_model(img_replaced_tensor_permute.unsqueeze(0).to(device))
pred = pred.cpu().detach().numpy().copy()
pred = np.where(pred>=0.5, 1, 0)

# %%
print(pred.shape)
_pred = np.squeeze(pred)
print(_pred.shape)

# %%
_pred_for_raw = loaded_model(img.unsqueeze(0).to(device))
_pred_for_raw = _pred_for_raw.cpu().detach().numpy().copy()
_pred_for_raw = np.where(_pred_for_raw>=0.5, 1, 0)
_pred_for_raw = np.squeeze(_pred_for_raw)

# %%
di = np.where(abs(_pred_for_raw-_pred)>0, 1, 0)

# %%
plt.figure(figsize=(12,12))
plt.subplot(1,5,1)
plt.imshow(_img_np_3band_from_4band)
plt.subplot(1,5,2)
plt.imshow(_mask_np_1band)
plt.subplot(1,5,3)
plt.imshow(_pred_for_raw)
plt.subplot(1,5,4)
plt.imshow(_pred)
plt.subplot(1,5,5)
plt.imshow(di)

# %%
img = img.permute(2,0,1)
img.shape

# %%
# change detection
loaded_model = loaded_model.to(device)
di_pred = loaded_model(img.unsqueeze(0), img_replaced_tensor_permute.unsqueeze(0))
di_pred = di_pred.cpu().detach().numpy().copy()
di_pred = np.where(di_pred>=0.5, 1, 0)

# %%
print(di_pred.shape)
_di_pred = np.squeeze(di_pred)
print(_di_pred.shape)

# %%
plt.figure(figsize=(12,12))
plt.subplot(1,3,1)
plt.imshow(_img_np_3band_from_4band)
plt.subplot(1,3,2)
plt.imshow(_mask_np_1band)
plt.subplot(1,3,3)
plt.imshow(_di_pred)

# %% [markdown]
# # Masuda urban areas

# %%
image1 = '../building_detection_data/masuda_sat_imgs/raw_img/PHR1B_acq20201112_Masuda_Urban.TIF'
image2 = '../building_detection_data/masuda_sat_imgs/raw_img/PHR1B_acq20210315_Masuda_Urban.TIF'

psh1 = rio.open(image1)
psh1_meta = psh1.meta
psh1 = psh1.read().transpose([1,2,0]).astype('float')

psh2 = rio.open(image2)
psh2_meta = psh2.meta
psh2 = psh2.read().transpose([1,2,0]).astype('float')

# %%
psh1.shape

# %%
# Image check
import utils
def stack_3band(img, i=1, j=2, k=4, gray=False):
    '''
    False color visuliazation
    [1,2,4] - RGB
    [7,3,1] - cement
    '''
    img_3band = np.stack([img[:, :, i],
                         img[:, :, j],
                         img[:, :, k]], axis=2)
    img_gray = (img[:, :, i] + img[:, :, j] + img[:, :, k]) / 3
    if gray:
        return img_gray[:, :, np.newaxis].astype('int32')
    else:
        return img_3band

psh_rgb1 = stack_3band(psh1, 0,1,2)
psh_rgb2 = stack_3band(psh2, 0,1,2)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (10, 6))
ax1.imshow(utils.scale_percentile(psh_rgb1))
ax1.set_title('20201112')
ax2.set_title('20210315')
ax2.imshow(utils.scale_percentile(psh_rgb2))

# %%
psh_rgb1.shape

# %%
_psh_rgb1 = psh_rgb1[1000+224*2:1000+224*3, 1000+224*2:1000+224*3]
#_psh_rgb2 = psh_rgb2[1000:1000+224*1, 1000:1000+224*1]

plt.imshow(utils.scale_percentile(_psh_rgb1))

# fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (10, 6))
# ax1.imshow(utils.scale_percentile(_psh_rgb1))
# ax1.set_title('20201112')
#ax2.set_title('20210315')
#ax2.imshow(utils.scale_percentile(_psh_rgb2))

# %%
_psh1 = psh1[1000+224*2:1000+224*3, 1000+224*2:1000+224*3, :]
# _psh1 = psh1[1000:1000+448, 1000:1000+448, :]
# img = Image.fromarray(np.uint8(_psh1))
# _psh1 = np.asarray(img.resize((224,224)))

_psh1.shape
# Out:
# (224, 224, 4)

# %%
#_psh1 = np.array(_psh1)
_psh1 = _psh1.transpose(2,0,1)
_psh1 = _psh1[np.newaxis,:,:,:]

# %%
pred = loaded_model(torch.from_numpy(_psh1.astype(np.float32)).to(device))
pred = pred.cpu().detach().numpy().squeeze()
#pred = np.where(pred>=0.5, 1, 0)
plt.imshow(pred)

# %%
type(_psh1)
